# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('lena.jpg',0) #0 - read colour, 1, read greyscale, -1 as is with alpha channel

# %%
print(img)
# Out:
# [[163 162 161 ... 170 154 130]
#  [162 162 162 ... 173 155 126]
#  [162 162 163 ... 170 155 128]
#  ...
#  [ 43  42  51 ... 103 101  99]
#  [ 41  42  55 ... 103 105 106]
#  [ 42  44  57 ... 102 106 109]]

# %%
h,w = img.shape[:2]
print(img.shape)
plt.imshow(img,cmap='gray')
plt.show()
# Out:
# (512, 512)
