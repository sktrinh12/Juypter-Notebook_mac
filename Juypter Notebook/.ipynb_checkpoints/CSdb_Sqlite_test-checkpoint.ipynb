# %%
import sqlite3
from sqlite3 import Error

def connecTo(db_file):
    try:
        conn = sqlite3.connect('file:{}?mode=rwc'.format(db_file),uri=True) #Read, Write & Create mode, so connecting to a non-existing database will cause it to be created
        return conn
    except Exception as e:
        print(e)

# %%
conn = connecTo('CSdb_addn.db')
c = conn.cursor()
res = c.execute('''PRAGMA table_info(CSdb_addn)''')
r = res.fetchall()

# %%
r
# Out:
# [(0, 'index', 'INTEGER', 0, None, 0),
#  (1, 'ChemSpider_ID', 'INTEGER', 0, None, 0),
#  (2, 'InChI_string', 'TEXT', 0, None, 0),
#  (3, 'Std_InChI', 'TEXT', 0, None, 0),
#  (4, 'Molecular_Formula', 'TEXT', 0, None, 0),
#  (5, 'Average_Mass', 'REAL', 0, None, 0),
#  (6, 'SMILES', 'TEXT', 0, None, 0),
#  (7, 'Common_Name', 'TEXT', 0, None, 0),
#  (8, 'Systematic_Name', 'TEXT', 0, None, 0),
#  (9, 'logP', 'REAL', 0, None, 0),
#  (10, 'H_Bond_Donors', 'INTEGER', 0, None, 0),
#  (11, 'H_Bond_Acceptors', 'INTEGER', 0, None, 0),
#  (12, 'Num_Rota_Bonds', 'INTEGER', 0, None, 0),
#  (13, 'Lipinski_Rule_5', 'INTEGER', 0, None, 0),
#  (14, 'Polar_Surface_Area', 'INTEGER', 0, None, 0),
#  (15, 'Enthalpy_Vap', 'TEXT', 0, None, 0),
#  (16, 'Density', 'TEXT', 0, None, 0),
#  (17, 'Boiling_Point', 'TEXT', 0, None, 0),
#  (18, 'Arom_rings', 'INTEGER', 0, None, 0),
#  (19, 'Num_Nitrogens', 'INTEGER', 0, None, 0),
#  (20, 'Num_Oxygens', 'INTEGER', 0, None, 0),
#  (21, 'SSSR', 'INTEGER', 0, None, 0),
# ...

# %%
res = c.execute('''SELECT CHEMSPIDER_ID, AVERAGE_MASS FROM CSDB_ADDN''').fetchall()
res
# Out:
# [(103, 184.041),
#  (134, 131.13),
#  (140, 473.439),
#  (185, 135.127),
#  (235, 106.122),
#  (292, 323.129),
#  (299, 104.17),
#  (431, 239.741),
#  (566, 131.133),
#  (659, 78.133),
#  (661, 153.178),
#  (733, 92.094),
#  (764, 110.111),
#  (815, 183.204),
#  (911, 122.125),
#  (913, 123.109),
#  (917, 162.232),
#  (937, 18.015),
#  (979, 97.995),
#  (989, 184.15),
#  (1017, 123.113),
#  (1020, 79.1),
#  (1032, 94.973),
#  (1042, 286.452),
#  (1085, 96.064),
#  (1141, 112.087),
#  (1143, 60.055),
#  (1169, 149.233),
#  (1262, 230.259),
#  (1556, 193.242),
#  (1628, 543.519),
#  (1664, 94.115),
#  (1710, 252.268),
#  (1739, 244.205),
#  (1906, 151.163),
#  (1909, 222.245),
#  (1916, 160.234),
#  (1945, 225.205),
#  (1998, 265.331),
#  (1999, 239.311),
#  (2004, 249.096),
#  (2010, 136.111),
#  (2015, 294.351),
#  (2034, 308.765),
#  (2055, 613.914),
#  (2056, 214.223),
#  (2068, 180.164),
#  (2072, 645.312),
#  (2075, 277.403),
#  (2077, 408.876),
#  (2102, 293.366),
# ...

# %%
res = c.execute('''SELECT * FROM CSDB_ADDN WHERE CHEMSPIDER_ID = '28518072' ''').fetchall()
res
# Out:
# [(None,
#   28518072,
#   'InChI=1S/C21H22N6O/c1-27-11-10-16(24-21(28)23-15-8-6-14(13-22)7-9-15)12-19(27)20-25-17-4-2-3-5-18(17)26-20/h2-9,16,19H,10-12H2,1H3,(H,25,26)(H2,23,24,28)/t16-,19-/m1/s1',
#   'SFNSLLSYNZWZQGVQIMIIECSA-N',
#   'C21H22N6O',
#   374.439,
#   'CN1CC[C@H](C[C@@H]1c2[nH]c3ccccc3n2)NC(=O)Nc4ccc(cc4)C#N',
#   'glasdegib',
#   '1-[(2R,4R)-2-(1H-Benzimidazol-2-yl)-1-methyl-4-piperidinyl]-3-(4-cyanophenyl)urea',
#   2.77,
#   3,
#   7,
#   4,
#   0,
#   b'a\x00\x00\x00\x00\x00\x00\x00',
#   '93.6±3.0 kJ/mol',
#   '1.3±0.1 g/cm3',
#   '633.4±55.0 °C at 760 mmHg',
#   3,
#   6,
#   1,
#   4,
#   2,
#   'non-NP',
#   0),
#  (None,
#   28518072,
#   'InChI=1S/C21H22N6O/c1-27-11-10-16(24-21(28)23-15-8-6-14(13-22)7-9-15)12-19(27)20-25-17-4-2-3-5-18(17)26-20/h2-9,16,19H,10-12H2,1H3,(H,25,26)(H2,23,24,28)/t16-,19-/m1/s1',
#   'SFNSLLSYNZWZQGVQIMIIECSA-N',
#   'C21H22N6O',
#   374.439,
#   'CN1CC[C@H](C[C@@H]1c2[nH]c3ccccc3n2)NC(=O)Nc4ccc(cc4)C#N',
#   'glasdegib',
# ...

# %%
import pandas as pd
dfm = pd.DataFrame(res)
dfm.columns = ['csid','amass']

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy.sql import exists
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, String, Integer, Numeric
from sqlalchemy import update
SQLALCHEMY_DATABASE_URI ='mysql://sktrinh12:bon78952@localhost/chemitrycmpds'
engine = create_engine(SQLALCHEMY_DATABASE_URI)
Session = sessionmaker(bind=engine)
session=Session()
Base = declarative_base()
class Chemcmpd(Base):
    __tablename__ = 'CSdb_addn'
    csid = Column('ChemSpider_ID',Integer,primary_key=True)
    cname = Column('Common_Name', String(120))
    stdinchi= Column('Std_InChI',String(200))
    amass= Column('Average_Mass',Numeric)
    smi = Column('SMILES',String(200))

# %%
for i in dfm['csid']:
        try:
            stmt = session.query(exists().where(Chemcmpd.csid==i)).scalar()
            if stmt:
                print(f'{i} was found in mysql db!')
                session.query(Chemcmpd).filter(Chemcmpd.csid==i).update({'amass':dfm['amass'][dfm['csid']==i].item()})
                session.commit()
            else:
                print(f'{i} NOT FOUND!')
                pass
        except Exception as e:
            print(f'something happened - {e}')
# Out:
# 103 was found in mysql db!
# 134 was found in mysql db!
# 140 was found in mysql db!
# 185 was found in mysql db!
# 235 was found in mysql db!
# 292 NOT FOUND!
# 299 was found in mysql db!
# 431 was found in mysql db!
# 566 was found in mysql db!
# 659 was found in mysql db!
# 661 was found in mysql db!
# 733 was found in mysql db!
# 764 was found in mysql db!
# 815 was found in mysql db!
# 911 was found in mysql db!
# 913 was found in mysql db!
# 917 was found in mysql db!
# 937 NOT FOUND!
# 979 was found in mysql db!
# 989 was found in mysql db!
# 1017 was found in mysql db!
# 1020 was found in mysql db!
# 1032 was found in mysql db!
# 1042 was found in mysql db!
# 1085 was found in mysql db!
# 1141 was found in mysql db!
# 1143 was found in mysql db!
# 1169 was found in mysql db!
# 1262 was found in mysql db!
# 1556 was found in mysql db!
# 1628 was found in mysql db!
# 1664 was found in mysql db!
# 1710 was found in mysql db!
# 1739 NOT FOUND!
# 1906 was found in mysql db!
# ...

# %%
update(Chemcmpd).where(Chemcmpd.csid==2010).values({'amass':dfm['amass'][dfm['csid']==2010].item()})

# %%
session.query(Chemcmpd).filter(Chemcmpd.csid==2010).update({'amass':amassUpdate})
session.commit()

# %%
session.query(Chemcmpd.csid,Chemcmpd.cname,Chemcmpd.stdinchi,Chemcmpd.amass,Chemcmpd.smi).filter_by(csid=2010).all()
# Out:
# [(2010,
#   'Zyloprim / Allopurinol',
#   'OFCNXPDARWKPPYUHFFFAOYSA-N',
#   Decimal('136.111'),
#   'c1c2c([nH]cnc2=O)[nH]n1')]

# %%
import pybel

x = pybel.readstring('smi',res1[0][1])
x
