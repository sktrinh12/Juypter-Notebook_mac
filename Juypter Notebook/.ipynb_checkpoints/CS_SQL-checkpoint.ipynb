# %%
import sqlite3
from sqlite3 import Error
import re
import pandas as pd
#import json
from indigo.indigo import *
#import matplotlib.pyplot as plt
#import numpy as np
import openbabel #must use python 3.6
import pybel
import webScrapeNPASSnCS
from selenium import webdriver
#%matplotlib inline

# %%
def create_connection(db_file):
    try:
        conn = sqlite3.connect('file:{}?mode=rwc'.format(db_file),uri=True) #Read, Write & Create mode, so connecting to a non-existing database will cause it to be created
        print('sqlite3 version: '+sqlite3.version+'\n==============\n')
        return conn
    except Exception as e:
        print(e)

def create_table(conn):
    c = conn.cursor()
    c.execute('''CREATE TABLE IF NOT EXISTS CStable (ChemSpider_ID INTEGER PRIMARY KEY, InChI_string TEXT, Std_InChI TEXT, 
                 Molecular_Formula TEXT, Average_Mass REAL, SMILES TEXT, Common_Name TEXT, Systematic_Name TEXT,
                 logP REAL,H_Bond_Donors INTEGER,H_Bond_Acceptors INTEGER,Num_Rota_Bonds INTEGER,Lipinski_Rule_5 INTEGER,
                 Polar_Surface_Area TEXT,Enthalpy_Vap REAL,Density REAL,Boiling_Point REAL)''')
    return c.lastrowid
#PSA is text because attached is the unit, angstrom which is text

def data_entry(conn,listOfProps,n,k):
    sql = '''INSERT INTO CStable (ChemSpider_ID,InChI_string,Std_InChI,Molecular_Formula,Average_Mass,
             SMILES,Common_Name,Systematic_Name,logP,H_Bond_Donors,H_Bond_Acceptors,Num_Rota_Bonds, 
             Lipinski_Rule_5,Polar_Surface_Area,Enthalpy_Vap,Density,Boiling_Point) 
             VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)'''
    c = conn.cursor()
    c.execute(sql,listOfProps)
    print('({}) {} -> Saved to SQL Table'.format(n,k))
    #n is counter, k is key from CSDict keys
def update_name(conn,nmID):
    sql = ''' UPDATE CStable SET Common_Name = ? WHERE ChemSpider_ID = ? '''
    c = conn.cursor()
    c.execute(sql,nmID) #list of names (new,CSID)
    conn.commit()
    print('Common Name for CS_ID: {} was changed to "{}"'.format(nmID[1],nmID[0]))
def update_data(conn, listOfProps,n,k):
    sql = ''' UPDATE CStable
              SET InChI_string = ?,Std_InChI = ?,Molecular_Formula = ?,Average_Mass =?,
              SMILES=?, Common_Name=?, Systematic_Name=?, logP=?, H_Bond_Donors=?, H_Bond_Acceptors=?, Num_Rota_Bonds=?, 
              Lipinski_Rule_5=?, Polar_Surface_Area=?, Enthalpy_Vap=?, Density=?,Boiling_Point=?
              WHERE ChemSpider_ID = ?'''
    c = conn.cursor()
    c.execute(sql, listOfProps)
    conn.commit()
    print('({}) {} -> Updated SQL Table'.format(n,k))
    
def delete_all_entries(conn):
    sql = '''DELETE FROM CStable'''
    c = conn.cursor()
    c.execute(sql)
    conn.commit()
def drop_table(conn):
    sql = '''DROP TABLE CStable'''
    c = conn.cursor()
    c.execute(sql)
    conn.commit()  
def get_sqlTable(conn):
    with conn:
        c = conn.cursor()
        c.execute("SELECT * FROM CStable")
        print(c.fetchall())
        
def unlock_db(db_filename):
    connection = create_connection(db_filename)
    connection.commit()
    connection.interrupt()
    connection.close()
    print('Connection closed')
    
def loopupdate(outerDict,n,k):
    loop =True
    while loop:
        updatentries = input('Do you want to update the TABLE entries for {}? (Y/N)'.format(k))
        if updatentries.lower() == 'y':
            try:
                update_data(conn,(outerDict[k]['InChI string'],outerDict[k]['Std InChI'],
                            outerDict[k]['Molecular Formula'],outerDict[k]['Average Mass (Da)'].replace(' Da',''),
                            outerDict[k]['SMILES'],outerDict[k]['Common Name'],outerDict[k]['Systematic Name'],
                            outerDict[k]['LogP'],outerDict[k]['H Bond Donors'],outerDict[k]['H Bond Acceptors'],
                            outerDict[k]['Num. Rotatable Bonds'],outerDict[k]['Lipinski Rule of 5'],
                            outerDict[k]['Polar Surface Area'],
                            outerDict[k]['Enthalpy of Vapourisation'],outerDict[k]['Density'],outerDict[k]['Boiling Point'],outerDict[k]['ChemSpider ID']), n, k)
                n+=1
                loop=False
            except Error as e:
                print(e)
                loop=False
        elif updatentries.lower() == 'n':
                loop=False
                pass
        else:
            print('\n\tEnter a valid entry.\n')
            print(updatentries)
    return n

# %%
#fnames = ['combDrgLst_1to200.txt','combDrgLst_200to400.txt','combDrgLst_400to600.txt',
#          'combDrgLst_600to800.txt','combDrgLst_800to1000.txt',
#          'combDrgLst_1000to1200.txt','combDrgLst_1200to1424.txt']

fnames = ['rxDrgLst_1to300.txt','rxDrgLst_300to700.txt',
          'rxDrgLst_700to1000.txt','rxDrgLst_1000to1300.txt',
         'rxDrgLst_1300toEnd.txt']

main_dict = {}

def ldComblst(fname):
    tmpdict = json.load(open(fname))
    return tmpdict

def mergDict(main_dict,fnames):
    for fn in fnames:
        tdict = ldComblst(fn)
        main_dict = {**main_dict, **tdict}
    return main_dict
        
main_dict = mergDict(main_dict,fnames)

# %%
len(main_dict.keys())

# %%
n = 1
conn = create_connection("CSdb.db")
with conn:
    cur=conn.cursor()
    create_table(conn)
    skip=True
    while skip:
        try:
            skiprepeats = str(input('Do you want to skip all the existing entries and only add new ones? '))
        except ValueError:
            print('\n\tEnter a valid entry (y/n).\n')
            continue
        if skiprepeats.lower() not in ['y','n']:
            print('\n\tEnter a valid entry (y/n).\n')
            continue
        else:
            skip=False
    for k in main_dict.keys():
        cur.execute("SELECT count(*) FROM CStable WHERE ChemSpider_ID = ?", (k,))
        data=cur.fetchone()[0]
        if data==0:
            try:
                data_entry(conn,(main_dict[k]['ChemSpider ID'],main_dict[k]['InChI string'],main_dict[k]['Std InChI'],
                            main_dict[k]['Molecular Formula'],main_dict[k]['Average Mass (Da)'].replace(' Da',''),
                            main_dict[k]['SMILES'],main_dict[k]['Common Name'],main_dict[k]['Systematic Name'],
                            main_dict[k]['LogP'],main_dict[k]['H Bond Donors'],main_dict[k]['H Bond Acceptors'],
                            main_dict[k]['Num. Rotatable Bonds'],main_dict[k]['Lipinski Rule of 5'],
                            main_dict[k]['Polar Surface Area'],
                            main_dict[k]['Enthalpy of Vapourisation'],main_dict[k]['Density'],main_dict[k]['Boiling Point']), n, k)
                n+=1
            except sqlite3.IntegrityError:
                print('\n{} - {} is already in CStable database, unique constraint failed'.format(n,k))
                loopupdate(main_dict,n,k)
        elif data!=0 and skiprepeats =='y': #entry exists in Table and skip all repeats
            pass
            print('\n({}) No new entires to add to the SQL Table.'.format(n))
            n+=1
        elif data!=0 and skiprepeats=='n': #if the CSID exists, and want to update
            loopupdate(main_dict,n,k)
# Out:
# sqlite3 version: 2.6.0
# ==============
#
# Do you want to skip all the existing entries and only add new ones? y
# (1) 103196 -> Saved to SQL Table
# (2) 30576 -> Saved to SQL Table
# (3) 29193 -> Saved to SQL Table
# (4) 8029718 -> Saved to SQL Table
#
# (5) No new entires to add to the SQL Table.
#
# (6) No new entires to add to the SQL Table.
# (7) 2624 -> Saved to SQL Table
#
# (8) No new entires to add to the SQL Table.
#
# (9) No new entires to add to the SQL Table.
#
# (10) No new entires to add to the SQL Table.
#
# (11) No new entires to add to the SQL Table.
#
# (12) No new entires to add to the SQL Table.
# (13) 431981 -> Saved to SQL Table
# (14) 5381 -> Saved to SQL Table
# (15) 64300 -> Saved to SQL Table
# (16) 5463 -> Saved to SQL Table
#
# (17) No new entires to add to the SQL Table.
# (18) 28530803 -> Saved to SQL Table
#
# (19) No new entires to add to the SQL Table.
# (20) 3978 -> Saved to SQL Table
#
# (21) No new entires to add to the SQL Table.
# (22) 33377 -> Saved to SQL Table
# (23) 4047 -> Saved to SQL Table
# (24) 34980598 -> Saved to SQL Table
# (25) 16351 -> Saved to SQL Table
# (26) 8223931 -> Saved to SQL Table
#
# (27) No new entires to add to the SQL Table.
# (28) 29837 -> Saved to SQL Table
# (29) 8499830 -> Saved to SQL Table
#
# (30) No new entires to add to the SQL Table.
#
# (31) No new entires to add to the SQL Table.
#
# (32) No new entires to add to the SQL Table.
# (33) 21378400 -> Saved to SQL Table
# (34) 10856 -> Saved to SQL Table
#
# (35) No new entires to add to the SQL Table.
# (36) 5961 -> Saved to SQL Table
# (37) 4748 -> Saved to SQL Table
# (38) 4447641 -> Saved to SQL Table
# (39) 2273807 -> Saved to SQL Table
#
# (40) No new entires to add to the SQL Table.
# (41) 5293353 -> Saved to SQL Table
# (42) 46260 -> Saved to SQL Table
# (43) 10162 -> Saved to SQL Table
# (44) 4586395 -> Saved to SQL Table
# (45) 10482043 -> Saved to SQL Table
# (46) 4766 -> Saved to SQL Table
#
# (47) No new entires to add to the SQL Table.
# (48) 2380 -> Saved to SQL Table
#
# (49) No new entires to add to the SQL Table.
#
# (50) No new entires to add to the SQL Table.
# (51) 10438564 -> Saved to SQL Table
#
# (52) No new entires to add to the SQL Table.
# (53) 2279 -> Saved to SQL Table
#
# (54) No new entires to add to the SQL Table.
#
# (55) No new entires to add to the SQL Table.
# (56) 5834 -> Saved to SQL Table
#
# (57) No new entires to add to the SQL Table.
#
# (58) No new entires to add to the SQL Table.
#
# (59) No new entires to add to the SQL Table.
# (60) 19349271 -> Saved to SQL Table
# (61) 2699 -> Saved to SQL Table
#
# (62) No new entires to add to the SQL Table.
#
# (63) No new entires to add to the SQL Table.
#
# (64) No new entires to add to the SQL Table.
#
# (65) No new entires to add to the SQL Table.
# (66) 3593 -> Saved to SQL Table
#
# (67) No new entires to add to the SQL Table.
#
# (68) No new entires to add to the SQL Table.
#
# (69) No new entires to add to the SQL Table.
# (70) 4750 -> Saved to SQL Table
# (71) 1265957 -> Saved to SQL Table
#
# (72) No new entires to add to the SQL Table.
# (73) 34980932 -> Saved to SQL Table
# (74) 4515032 -> Saved to SQL Table
#
# (75) No new entires to add to the SQL Table.
# (76) 4308 -> Saved to SQL Table
#
# (77) No new entires to add to the SQL Table.
#
# (78) No new entires to add to the SQL Table.
# (79) 10455 -> Saved to SQL Table
# (80) 4445597 -> Saved to SQL Table
#
# (81) No new entires to add to the SQL Table.
# (82) 3438 -> Saved to SQL Table
#
# (83) No new entires to add to the SQL Table.
#
# (84) No new entires to add to the SQL Table.
# (85) 8209640 -> Saved to SQL Table
# (86) 392351 -> Saved to SQL Table
#
# (87) No new entires to add to the SQL Table.
#
# (88) No new entires to add to the SQL Table.
# (89) 4884384 -> Saved to SQL Table
#
# (90) No new entires to add to the SQL Table.
# (91) 135903 -> Saved to SQL Table
#
# (92) No new entires to add to the SQL Table.
# (93) 4444059 -> Saved to SQL Table
#
# (94) No new entires to add to the SQL Table.
# (95) 6619 -> Saved to SQL Table
# (96) 6257 -> Saved to SQL Table
# (97) 571424 -> Saved to SQL Table
# (98) 6002 -> Saved to SQL Table
# (99) 2337 -> Saved to SQL Table
# (100) 51990 -> Saved to SQL Table
# (101) 43503 -> Saved to SQL Table
# (102) 59273 -> Saved to SQL Table
# (103) 5129 -> Saved to SQL Table
#
# (104) No new entires to add to the SQL Table.
#
# (105) No new entires to add to the SQL Table.
#
# (106) No new entires to add to the SQL Table.
#
# (107) No new entires to add to the SQL Table.
#
# (108) No new entires to add to the SQL Table.
# (109) 54923 -> Saved to SQL Table
# (110) 8012964 -> Saved to SQL Table
# (111) 8995866 -> Saved to SQL Table
#
# (112) No new entires to add to the SQL Table.
#
# (113) No new entires to add to the SQL Table.
#
# (114) No new entires to add to the SQL Table.
#
# (115) No new entires to add to the SQL Table.
# (116) 4514524 -> Saved to SQL Table
#
# (117) No new entires to add to the SQL Table.
#
# (118) No new entires to add to the SQL Table.
#
# (119) No new entires to add to the SQL Table.
#
# (120) No new entires to add to the SQL Table.
#
# (121) No new entires to add to the SQL Table.
# (122) 3237 -> Saved to SQL Table
#
# (123) No new entires to add to the SQL Table.
# (124) 388759 -> Saved to SQL Table
#
# (125) No new entires to add to the SQL Table.
#
# (126) No new entires to add to the SQL Table.
#
# (127) No new entires to add to the SQL Table.
#
# (128) No new entires to add to the SQL Table.
#
# (129) No new entires to add to the SQL Table.
#
# (130) No new entires to add to the SQL Table.
#
# (131) No new entires to add to the SQL Table.
#
# (132) No new entires to add to the SQL Table.
# (133) 32689915 -> Saved to SQL Table
# (134) 9494 -> Saved to SQL Table
# (135) 2425 -> Saved to SQL Table
# (136) 4341 -> Saved to SQL Table
#
# (137) No new entires to add to the SQL Table.
# (138) 390041 -> Saved to SQL Table
#
# (139) No new entires to add to the SQL Table.
# (140) 392009 -> Saved to SQL Table
#
# (141) No new entires to add to the SQL Table.
#
# (142) No new entires to add to the SQL Table.
#
# (143) No new entires to add to the SQL Table.
# (144) 5293384 -> Saved to SQL Table
# (145) 8395995 -> Saved to SQL Table
# (146) 47904 -> Saved to SQL Table
# (147) 3525 -> Saved to SQL Table
# (148) 2272112 -> Saved to SQL Table
#
# (149) No new entires to add to the SQL Table.
#
# (150) No new entires to add to the SQL Table.
# (151) 4447652 -> Saved to SQL Table
# (152) 34369 -> Saved to SQL Table
#
# (153) No new entires to add to the SQL Table.
# (154) 19599 -> Saved to SQL Table
# (155) 2015 -> Saved to SQL Table
# (156) 3605 -> Saved to SQL Table
#
# (157) No new entires to add to the SQL Table.
#
# (158) No new entires to add to the SQL Table.
# (159) 28651973 -> Saved to SQL Table
# (160) 3292 -> Saved to SQL Table
#
# (161) No new entires to add to the SQL Table.
# (162) 8089417 -> Saved to SQL Table
# (163) 10482314 -> Saved to SQL Table
#
# (164) No new entires to add to the SQL Table.
# (165) 5643 -> Saved to SQL Table
# (166) 4674940 -> Saved to SQL Table
#
# (167) No new entires to add to the SQL Table.
#
# (168) No new entires to add to the SQL Table.
#
# (169) No new entires to add to the SQL Table.
# (170) 7933 -> Saved to SQL Table
#
# (171) No new entires to add to the SQL Table.
#
# (172) No new entires to add to the SQL Table.
# (173) 43067 -> Saved to SQL Table
# (174) 4444532 -> Saved to SQL Table
# (175) 2454 -> Saved to SQL Table
# (176) 2466 -> Saved to SQL Table
# (177) 10393 -> Saved to SQL Table
#
# (178) No new entires to add to the SQL Table.
#
# (179) No new entires to add to the SQL Table.
# (180) 40130 -> Saved to SQL Table
#
# (181) No new entires to add to the SQL Table.
# (182) 25999972 -> Saved to SQL Table
# (183) 2485 -> Saved to SQL Table
#
# (184) No new entires to add to the SQL Table.
#
# (185) No new entires to add to the SQL Table.
# (186) 5027 -> Saved to SQL Table
# (187) 1143 -> Saved to SQL Table
# (188) 4587145 -> Saved to SQL Table
#
# (189) No new entires to add to the SQL Table.
# (190) 4444306 -> Saved to SQL Table
#
# (191) No new entires to add to the SQL Table.
# (192) 559095 -> Saved to SQL Table
# (193) 4319 -> Saved to SQL Table
# (194) 75707 -> Saved to SQL Table
# (195) 8046534 -> Saved to SQL Table
#
# (196) No new entires to add to the SQL Table.
# (197) 4586394 -> Saved to SQL Table
# (198) 13863645 -> Saved to SQL Table
#
# (199) No new entires to add to the SQL Table.
#
# (200) No new entires to add to the SQL Table.
# (201) 57620495 -> Saved to SQL Table
# (202) 5980 -> Saved to SQL Table
#
# (203) No new entires to add to the SQL Table.
# (204) 2632 -> Saved to SQL Table
# (205) 8293 -> Saved to SQL Table
# (206) 299 -> Saved to SQL Table
#
# (207) No new entires to add to the SQL Table.
#
# (208) No new entires to add to the SQL Table.
# (209) 10248513 -> Saved to SQL Table
# (210) 25999973 -> Saved to SQL Table
# (211) 8114326 -> Saved to SQL Table
# (212) 30723 -> Saved to SQL Table
#
# (213) No new entires to add to the SQL Table.
# (214) 25129 -> Saved to SQL Table
#
# (215) No new entires to add to the SQL Table.
# (216) 2687 -> Saved to SQL Table
# (217) 135722 -> Saved to SQL Table
#
# (218) No new entires to add to the SQL Table.
#
# (219) No new entires to add to the SQL Table.
# (220) 4444353 -> Saved to SQL Table
#
# (221) No new entires to add to the SQL Table.
#
# (222) No new entires to add to the SQL Table.
#
# (223) No new entires to add to the SQL Table.
#
# (224) No new entires to add to the SQL Table.
#
# (225) No new entires to add to the SQL Table.
#
# (226) No new entires to add to the SQL Table.
#
# (227) No new entires to add to the SQL Table.
#
# (228) No new entires to add to the SQL Table.
# (229) 56615 -> Saved to SQL Table
# (230) 4674877 -> Saved to SQL Table
#
# (231) No new entires to add to the SQL Table.
#
# (232) No new entires to add to the SQL Table.
#
# (233) No new entires to add to the SQL Table.
# (234) 25084912 -> Saved to SQL Table
# (235) 4470591 -> Saved to SQL Table
#
# (236) No new entires to add to the SQL Table.
#
# (237) No new entires to add to the SQL Table.
#
# (238) No new entires to add to the SQL Table.
#
# (239) No new entires to add to the SQL Table.
#
# (240) No new entires to add to the SQL Table.
# (241) 389987 -> Saved to SQL Table
# (242) 133239 -> Saved to SQL Table
# (243) 2779 -> Saved to SQL Table
# (244) 23240540 -> Saved to SQL Table
#
# (245) No new entires to add to the SQL Table.
#
# (246) No new entires to add to the SQL Table.
# (247) 2802 -> Saved to SQL Table
# (248) 193441 -> Saved to SQL Table
#
# (249) No new entires to add to the SQL Table.
# (250) 14475 -> Saved to SQL Table
#
# (251) No new entires to add to the SQL Table.
#
# (252) No new entires to add to the SQL Table.
# (253) 2810 -> Saved to SQL Table
# (254) 1664 -> Saved to SQL Table
#
# (255) No new entires to add to the SQL Table.
# (256) 26331705 -> Saved to SQL Table
# (257) 392054 -> Saved to SQL Table
#
# (258) No new entires to add to the SQL Table.
#
# (259) No new entires to add to the SQL Table.
# (260) 10454538 -> Saved to SQL Table
# (261) 29776744 -> Saved to SQL Table
#
# (262) No new entires to add to the SQL Table.
# (263) 599515 -> Saved to SQL Table
#
# (264) No new entires to add to the SQL Table.
# (265) 5423 -> Saved to SQL Table
#
# (266) No new entires to add to the SQL Table.
# (267) 427049 -> Saved to SQL Table
# (268) 37400 -> Saved to SQL Table
# (269) 164861 -> Saved to SQL Table
#
# (270) No new entires to add to the SQL Table.
# (271) 5145991 -> Saved to SQL Table
# (272) 4470603 -> Saved to SQL Table
# (273) 17290939 -> Saved to SQL Table
# (274) 5290202 -> Saved to SQL Table
#
# (275) No new entires to add to the SQL Table.
#
# (276) No new entires to add to the SQL Table.
#
# (277) No new entires to add to the SQL Table.
#
# (278) No new entires to add to the SQL Table.
# (279) 2888 -> Saved to SQL Table
# (280) 31620 -> Saved to SQL Table
# (281) 2930 -> Saved to SQL Table
# (282) 2055 -> Saved to SQL Table
#
# (283) No new entires to add to the SQL Table.
#
# (284) No new entires to add to the SQL Table.
# (285) 10482117 -> Saved to SQL Table
#
# (286) No new entires to add to the SQL Table.
#
# (287) No new entires to add to the SQL Table.
#
# (288) No new entires to add to the SQL Table.
# (289) 391990 -> Saved to SQL Table
# (290) 4470605 -> Saved to SQL Table
#
# (291) No new entires to add to the SQL Table.
#
# (292) No new entires to add to the SQL Table.
#
# (293) No new entires to add to the SQL Table.
# (294) 12919 -> Saved to SQL Table
#
# (295) No new entires to add to the SQL Table.
# (296) 2911 -> Saved to SQL Table
#
# (297) No new entires to add to the SQL Table.
# (298) 3002 -> Saved to SQL Table
# (299) 10091 -> Saved to SQL Table
# (300) 28424197 -> Saved to SQL Table
# (301) 20490 -> Saved to SQL Table
# (302) 3005 -> Saved to SQL Table
# (303) 54249 -> Saved to SQL Table
# (304) 23152451 -> Saved to SQL Table
#
# (305) No new entires to add to the SQL Table.
# (306) 66040 -> Saved to SQL Table
# (307) 96749 -> Saved to SQL Table
# (308) 64504 -> Saved to SQL Table
#
# (309) No new entires to add to the SQL Table.
#
# (310) No new entires to add to the SQL Table.
# (311) 4444554 -> Saved to SQL Table
# (312) 4447604 -> Saved to SQL Table
#
# (313) No new entires to add to the SQL Table.
# (314) 1909 -> Saved to SQL Table
#
# (315) No new entires to add to the SQL Table.
# (316) 180996 -> Saved to SQL Table
#
# (317) No new entires to add to the SQL Table.
# (318) 16736416 -> Saved to SQL Table
#
# (319) No new entires to add to the SQL Table.
# (320) 3046 -> Saved to SQL Table
#
# (321) No new entires to add to the SQL Table.
#
# (322) No new entires to add to the SQL Table.
#
# (323) No new entires to add to the SQL Table.
#
# (324) No new entires to add to the SQL Table.
#
# (325) No new entires to add to the SQL Table.
# (326) 3225 -> Saved to SQL Table
#
# (327) No new entires to add to the SQL Table.
# (328) 3050 -> Saved to SQL Table
#
# (329) No new entires to add to the SQL Table.
# (330) 3224 -> Saved to SQL Table
# (331) 83927 -> Saved to SQL Table
# (332) 3652 -> Saved to SQL Table
# (333) 3220 -> Saved to SQL Table
#
# (334) No new entires to add to the SQL Table.
# (335) 9742243 -> Saved to SQL Table
#
# (336) No new entires to add to the SQL Table.
# (337) 31719 -> Saved to SQL Table
# (338) 2179 -> Saved to SQL Table
# (339) 82611 -> Saved to SQL Table
#
# (340) No new entires to add to the SQL Table.
# (341) 5293755 -> Saved to SQL Table
# (342) 29111 -> Saved to SQL Table
#
# (343) No new entires to add to the SQL Table.
#
# (344) No new entires to add to the SQL Table.
# (345) 8282919 -> Saved to SQL Table
#
# (346) No new entires to add to the SQL Table.
# (347) 28492333 -> Saved to SQL Table
# (348) 3276 -> Saved to SQL Table
# (349) 3267 -> Saved to SQL Table
# (350) 5293454 -> Saved to SQL Table
# (351) 15968 -> Saved to SQL Table
#
# (352) No new entires to add to the SQL Table.
# (353) 571392 -> Saved to SQL Table
# (354) 74144 -> Saved to SQL Table
# (355) 6205 -> Saved to SQL Table
#
# (356) No new entires to add to the SQL Table.
# (357) 189912 -> Saved to SQL Table
# (358) 148702 -> Saved to SQL Table
# (359) 50839 -> Saved to SQL Table
# (360) 116245 -> Saved to SQL Table
#
# (361) No new entires to add to the SQL Table.
# (362) 2302062 -> Saved to SQL Table
# (363) 3266 -> Saved to SQL Table
# (364) 3297 -> Saved to SQL Table
#
# (365) No new entires to add to the SQL Table.
# (366) 7845573 -> Saved to SQL Table
#
# (367) No new entires to add to the SQL Table.
#
# (368) No new entires to add to the SQL Table.
#
# (369) No new entires to add to the SQL Table.
# (370) 3277 -> Saved to SQL Table
#
# (371) No new entires to add to the SQL Table.
# (372) 70378 -> Saved to SQL Table
#
# (373) No new entires to add to the SQL Table.
# (374) 9272 -> Saved to SQL Table
#
# (375) No new entires to add to the SQL Table.
# (376) 3336 -> Saved to SQL Table
# (377) 3374 -> Saved to SQL Table
# (378) 10482016 -> Saved to SQL Table
# (379) 17288942 -> Saved to SQL Table
# (380) 2301017 -> Saved to SQL Table
#
# (381) No new entires to add to the SQL Table.
#
# (382) No new entires to add to the SQL Table.
#
# (383) No new entires to add to the SQL Table.
# (384) 3398 -> Saved to SQL Table
#
# (385) No new entires to add to the SQL Table.
# (386) 733 -> Saved to SQL Table
# (387) 391997 -> Saved to SQL Table
# (388) 4938272 -> Saved to SQL Table
# (389) 4470691 -> Saved to SQL Table
# (390) 3392 -> Saved to SQL Table
#
# (391) No new entires to add to the SQL Table.
#
# (392) No new entires to add to the SQL Table.
# (393) 10482012 -> Saved to SQL Table
# (394) 259688 -> Saved to SQL Table
#
# (395) No new entires to add to the SQL Table.
#
# (396) No new entires to add to the SQL Table.
#
# (397) No new entires to add to the SQL Table.
#
# (398) No new entires to add to the SQL Table.
# (399) 764 -> Saved to SQL Table
# (400) 54755 -> Saved to SQL Table
#
# (401) No new entires to add to the SQL Table.
#
# (402) No new entires to add to the SQL Table.
# (403) 64459 -> Saved to SQL Table
# (404) 8108821 -> Saved to SQL Table
# (405) 71358 -> Saved to SQL Table
# (406) 4515036 -> Saved to SQL Table
#
# (407) No new entires to add to the SQL Table.
#
# (408) No new entires to add to the SQL Table.
# (409) 10282511 -> Saved to SQL Table
#
# (410) No new entires to add to the SQL Table.
#
# (411) No new entires to add to the SQL Table.
# (412) 5670 -> Saved to SQL Table
# (413) 3608 -> Saved to SQL Table
#
# (414) No new entires to add to the SQL Table.
# (415) 58940 -> Saved to SQL Table
# (416) 94631 -> Saved to SQL Table
#
# (417) No new entires to add to the SQL Table.
#
# (418) No new entires to add to the SQL Table.
#
# (419) No new entires to add to the SQL Table.
# (420) 3610 -> Saved to SQL Table
#
# (421) No new entires to add to the SQL Table.
#
# (422) No new entires to add to the SQL Table.
# (423) 82653 -> Saved to SQL Table
# (424) 3611 -> Saved to SQL Table
#
# (425) No new entires to add to the SQL Table.
#
# (426) No new entires to add to the SQL Table.
#
# (427) No new entires to add to the SQL Table.
#
# (428) No new entires to add to the SQL Table.
# (429) 3695 -> Saved to SQL Table
# (430) 5746 -> Saved to SQL Table
#
# (431) No new entires to add to the SQL Table.
#
# (432) No new entires to add to the SQL Table.
# (433) 16736314 -> Saved to SQL Table
#
# (434) No new entires to add to the SQL Table.
#
# (435) No new entires to add to the SQL Table.
#
# (436) No new entires to add to the SQL Table.
#
# (437) No new entires to add to the SQL Table.
#
# (438) No new entires to add to the SQL Table.
# (439) 28527877 -> Saved to SQL Table
#
# (440) No new entires to add to the SQL Table.
#
# (441) No new entires to add to the SQL Table.
# (442) 110192 -> Saved to SQL Table
#
# (443) No new entires to add to the SQL Table.
# (444) 26352849 -> Saved to SQL Table
#
# (445) No new entires to add to the SQL Table.
#
# (446) No new entires to add to the SQL Table.
#
# (447) No new entires to add to the SQL Table.
#
# (448) No new entires to add to the SQL Table.
#
# (449) No new entires to add to the SQL Table.
#
# (450) No new entires to add to the SQL Table.
# (451) 10139520 -> Saved to SQL Table
# (452) 17314504 -> Saved to SQL Table
# (453) 26418 -> Saved to SQL Table
# (454) 3694 -> Saved to SQL Table
#
# (455) No new entires to add to the SQL Table.
# (456) 28460 -> Saved to SQL Table
#
# (457) No new entires to add to the SQL Table.
#
# (458) No new entires to add to the SQL Table.
# (459) 10481896 -> Saved to SQL Table
#
# (460) No new entires to add to the SQL Table.
# (461) 22753753 -> Saved to SQL Table
#
# (462) No new entires to add to the SQL Table.
#
# (463) No new entires to add to the SQL Table.
# (464) 40543 -> Saved to SQL Table
# (465) 24344 -> Saved to SQL Table
#
# (466) No new entires to add to the SQL Table.
# (467) 3811 -> Saved to SQL Table
#
# (468) No new entires to add to the SQL Table.
#
# (469) No new entires to add to the SQL Table.
#
# (470) No new entires to add to the SQL Table.
# (471) 8028764 -> Saved to SQL Table
#
# (472) No new entires to add to the SQL Table.
# (473) 28529616 -> Saved to SQL Table
#
# (474) No new entires to add to the SQL Table.
#
# (475) No new entires to add to the SQL Table.
#
# (476) No new entires to add to the SQL Table.
#
# (477) No new entires to add to the SQL Table.
#
# (478) No new entires to add to the SQL Table.
# (479) 3858 -> Saved to SQL Table
#
# (480) No new entires to add to the SQL Table.
#
# (481) No new entires to add to the SQL Table.
#
# (482) No new entires to add to the SQL Table.
#
# (483) No new entires to add to the SQL Table.
#
# (484) No new entires to add to the SQL Table.
# (485) 9833595 -> Saved to SQL Table
# (486) 3892 -> Saved to SQL Table
#
# (487) No new entires to add to the SQL Table.
# (488) 3890 -> Saved to SQL Table
# (489) 216968 -> Saved to SQL Table
#
# (490) No new entires to add to the SQL Table.
#
# (491) No new entires to add to the SQL Table.
# (492) 26328096 -> Saved to SQL Table
# (493) 9794910 -> Saved to SQL Table
# (494) 8041134 -> Saved to SQL Table
#
# (495) No new entires to add to the SQL Table.
#
# (496) No new entires to add to the SQL Table.
# (497) 3917 -> Saved to SQL Table
# (498) 1916 -> Saved to SQL Table
#
# (499) No new entires to add to the SQL Table.
#
# (500) No new entires to add to the SQL Table.
# (501) 3918 -> Saved to SQL Table
# (502) 3959 -> Saved to SQL Table
# (503) 8665 -> Saved to SQL Table
# (504) 3924 -> Saved to SQL Table
# (505) 8683 -> Saved to SQL Table
# (506) 3944 -> Saved to SQL Table
# (507) 3971 -> Saved to SQL Table
#
# (508) No new entires to add to the SQL Table.
#
# (509) No new entires to add to the SQL Table.
# (510) 9300 -> Saved to SQL Table
# (511) 419105 -> Saved to SQL Table
#
# (512) No new entires to add to the SQL Table.
# (513) 7175 -> Saved to SQL Table
#
# (514) No new entires to add to the SQL Table.
# (515) 5788 -> Saved to SQL Table
#
# (516) No new entires to add to the SQL Table.
# (517) 3922 -> Saved to SQL Table
# (518) 3473 -> Saved to SQL Table
# (519) 4044 -> Saved to SQL Table
# (520) 16744285 -> Saved to SQL Table
# (521) 35562 -> Saved to SQL Table
# (522) 4034 -> Saved to SQL Table
#
# (523) No new entires to add to the SQL Table.
#
# (524) No new entires to add to the SQL Table.
# (525) 82418 -> Saved to SQL Table
#
# (526) No new entires to add to the SQL Table.
#
# (527) No new entires to add to the SQL Table.
# (528) 59245 -> Saved to SQL Table
# (529) 22342 -> Saved to SQL Table
#
# (530) No new entires to add to the SQL Table.
#
# (531) No new entires to add to the SQL Table.
# (532) 4470813 -> Saved to SQL Table
# (533) 8634 -> Saved to SQL Table
# (534) 10482014 -> Saved to SQL Table
#
# (535) No new entires to add to the SQL Table.
#
# (536) No new entires to add to the SQL Table.
#
# (537) No new entires to add to the SQL Table.
#
# (538) No new entires to add to the SQL Table.
# (539) 43344 -> Saved to SQL Table
# (540) 4447642 -> Saved to SQL Table
# (541) 153388 -> Saved to SQL Table
#
# (542) No new entires to add to the SQL Table.
#
# (543) No new entires to add to the SQL Table.
# (544) 66071 -> Saved to SQL Table
# (545) 8075 -> Saved to SQL Table
# (546) 22901017 -> Saved to SQL Table
# (547) 28651656 -> Saved to SQL Table
#
# (548) No new entires to add to the SQL Table.
#
# (549) No new entires to add to the SQL Table.
# (550) 45608 -> Saved to SQL Table
# (551) 4268 -> Saved to SQL Table
#
# (552) No new entires to add to the SQL Table.
#
# (553) No new entires to add to the SQL Table.
# (554) 7985471 -> Saved to SQL Table
# (555) 103195 -> Saved to SQL Table
# (556) 57718 -> Saved to SQL Table
#
# (557) No new entires to add to the SQL Table.
#
# (558) No new entires to add to the SQL Table.
# (559) 1262 -> Saved to SQL Table
# (560) 4301 -> Saved to SQL Table
# (561) 11460750 -> Saved to SQL Table
#
# (562) No new entires to add to the SQL Table.
#
# (563) No new entires to add to the SQL Table.
#
# (564) No new entires to add to the SQL Table.
#
# (565) No new entires to add to the SQL Table.
#
# (566) No new entires to add to the SQL Table.
#
# (567) No new entires to add to the SQL Table.
#
# (568) No new entires to add to the SQL Table.
#
# (569) No new entires to add to the SQL Table.
# (570) 58793 -> Saved to SQL Table
#
# (571) No new entires to add to the SQL Table.
#
# (572) No new entires to add to the SQL Table.
# (573) 9679097 -> Saved to SQL Table
# (574) 31149229 -> Saved to SQL Table
#
# (575) No new entires to add to the SQL Table.
#
# (576) No new entires to add to the SQL Table.
#
# (577) No new entires to add to the SQL Table.
#
# (578) No new entires to add to the SQL Table.
# (579) 10642377 -> Saved to SQL Table
#
# (580) No new entires to add to the SQL Table.
# (581) 20538 -> Saved to SQL Table
#
# (582) No new entires to add to the SQL Table.
# (583) 4453 -> Saved to SQL Table
# (584) 4440 -> Saved to SQL Table
#
# (585) No new entires to add to the SQL Table.
#
# (586) No new entires to add to the SQL Table.
#
# (587) No new entires to add to the SQL Table.
# (588) 4475 -> Saved to SQL Table
# (589) 388434 -> Saved to SQL Table
#
# (590) No new entires to add to the SQL Table.
#
# (591) No new entires to add to the SQL Table.
#
# (592) No new entires to add to the SQL Table.
#
# (593) No new entires to add to the SQL Table.
#
# (594) No new entires to add to the SQL Table.
# (595) 2298564 -> Saved to SQL Table
# (596) 388394 -> Saved to SQL Table
# (597) 8117062 -> Saved to SQL Table
# (598) 8039521 -> Saved to SQL Table
# (599) 2300501 -> Saved to SQL Table
#
# (600) No new entires to add to the SQL Table.
#
# (601) No new entires to add to the SQL Table.
# (602) 4518 -> Saved to SQL Table
# (603) 145115 -> Saved to SQL Table
#
# (604) No new entires to add to the SQL Table.
#
# (605) No new entires to add to the SQL Table.
# (606) 4573 -> Saved to SQL Table
#
# (607) No new entires to add to the SQL Table.
# (608) 6192 -> Saved to SQL Table
# (609) 96956 -> Saved to SQL Table
# (610) 4578 -> Saved to SQL Table
# (611) 111589 -> Saved to SQL Table
# (612) 11950 -> Saved to SQL Table
#
# (613) No new entires to add to the SQL Table.
# (614) 4599 -> Saved to SQL Table
#
# (615) No new entires to add to the SQL Table.
# (616) 8246736 -> Saved to SQL Table
# (617) 26390008 -> Saved to SQL Table
#
# (618) No new entires to add to the SQL Table.
# (619) 4586 -> Saved to SQL Table
# (620) 28530494 -> Saved to SQL Table
#
# (621) No new entires to add to the SQL Table.
# (622) 390052 -> Saved to SQL Table
#
# (623) No new entires to add to the SQL Table.
# (624) 10108 -> Saved to SQL Table
# (625) 10482174 -> Saved to SQL Table
# (626) 5571 -> Saved to SQL Table
#
# (627) No new entires to add to the SQL Table.
# (628) 5818 -> Saved to SQL Table
#
# (629) No new entires to add to the SQL Table.
# (630) 570993 -> Saved to SQL Table
#
# (631) No new entires to add to the SQL Table.
#
# (632) No new entires to add to the SQL Table.
# (633) 4445604 -> Saved to SQL Table
# (634) 5193737 -> Saved to SQL Table
#
# (635) No new entires to add to the SQL Table.
#
# (636) No new entires to add to the SQL Table.
#
# (637) No new entires to add to the SQL Table.
# (638) 411709 -> Saved to SQL Table
# (639) 4724 -> Saved to SQL Table
# (640) 4744 -> Saved to SQL Table
# (641) 4742 -> Saved to SQL Table
#
# (642) No new entires to add to the SQL Table.
#
# (643) No new entires to add to the SQL Table.
#
# (644) No new entires to add to the SQL Table.
#
# (645) No new entires to add to the SQL Table.
# (646) 4052 -> Saved to SQL Table
#
# (647) No new entires to add to the SQL Table.
# (648) 4825 -> Saved to SQL Table
# (649) 6761 -> Saved to SQL Table
#
# (650) No new entires to add to the SQL Table.
# (651) 4470884 -> Saved to SQL Table
#
# (652) No new entires to add to the SQL Table.
#
# (653) No new entires to add to the SQL Table.
#
# (654) No new entires to add to the SQL Table.
# (655) 2340876 -> Saved to SQL Table
#
# (656) No new entires to add to the SQL Table.
# (657) 389880 -> Saved to SQL Table
# (658) 4471557 -> Saved to SQL Table
# (659) 9696 -> Saved to SQL Table
#
# (660) No new entires to add to the SQL Table.
#
# (661) No new entires to add to the SQL Table.
#
# (662) No new entires to add to the SQL Table.
#
# (663) No new entires to add to the SQL Table.
#
# (664) No new entires to add to the SQL Table.
#
# (665) No new entires to add to the SQL Table.
#
# (666) No new entires to add to the SQL Table.
# (667) 390053 -> Saved to SQL Table
#
# (668) No new entires to add to the SQL Table.
#
# (669) No new entires to add to the SQL Table.
# (670) 9479719 -> Saved to SQL Table
# (671) 4892 -> Saved to SQL Table
#
# (672) No new entires to add to the SQL Table.
# (673) 6082 -> Saved to SQL Table
#
# (674) No new entires to add to the SQL Table.
#
# (675) No new entires to add to the SQL Table.
#
# (676) No new entires to add to the SQL Table.
#
# (677) No new entires to add to the SQL Table.
# (678) 64839 -> Saved to SQL Table
# (679) 9998301 -> Saved to SQL Table
# (680) 153165 -> Saved to SQL Table
# (681) 114471 -> Saved to SQL Table
# (682) 4447574 -> Saved to SQL Table
#
# (683) No new entires to add to the SQL Table.
#
# (684) No new entires to add to the SQL Table.
# (685) 116349 -> Saved to SQL Table
# (686) 17289071 -> Saved to SQL Table
#
# (687) No new entires to add to the SQL Table.
#
# (688) No new entires to add to the SQL Table.
#
# (689) No new entires to add to the SQL Table.
# (690) 5005 -> Saved to SQL Table
#
# (691) No new entires to add to the SQL Table.
#
# (692) No new entires to add to the SQL Table.
#
# (693) No new entires to add to the SQL Table.
#
# (694) No new entires to add to the SQL Table.
#
# (695) No new entires to add to the SQL Table.
# (696) 24930 -> Saved to SQL Table
#
# (697) No new entires to add to the SQL Table.
#
# (698) No new entires to add to the SQL Table.
# (699) 5036307 -> Saved to SQL Table
# (700) 8067637 -> Saved to SQL Table
# (701) 10481900 -> Saved to SQL Table
#
# (702) No new entires to add to the SQL Table.
# (703) 5394 -> Saved to SQL Table
# (704) 5123 -> Saved to SQL Table
# (705) 10482084 -> Saved to SQL Table
#
# (706) No new entires to add to the SQL Table.
#
# (707) No new entires to add to the SQL Table.
# (708) 38043 -> Saved to SQL Table
#
# (709) No new entires to add to the SQL Table.
# (710) 16218 -> Saved to SQL Table
# (711) 5148 -> Saved to SQL Table
# (712) 5188 -> Saved to SQL Table
# (713) 24662178 -> Saved to SQL Table
#
# (714) No new entires to add to the SQL Table.
# (715) 2338980 -> Saved to SQL Table
#
# (716) No new entires to add to the SQL Table.
# (717) 17281586 -> Saved to SQL Table
# (718) 8013742 -> Saved to SQL Table
#
# (719) No new entires to add to the SQL Table.
# (720) 59726 -> Saved to SQL Table
#
# (721) No new entires to add to the SQL Table.
#
# (722) No new entires to add to the SQL Table.
#
# (723) No new entires to add to the SQL Table.
#
# (724) No new entires to add to the SQL Table.
# (725) 5210 -> Saved to SQL Table
# (726) 10609889 -> Saved to SQL Table
#
# (727) No new entires to add to the SQL Table.
# (728) 2272258 -> Saved to SQL Table
#
# (729) No new entires to add to the SQL Table.
# (730) 10257122 -> Saved to SQL Table
# (731) 5218 -> Saved to SQL Table
#
# (732) No new entires to add to the SQL Table.
# (733) 28189675 -> Saved to SQL Table
# (734) 5585 -> Saved to SQL Table
# (735) 33876 -> Saved to SQL Table
#
# (736) No new entires to add to the SQL Table.
# (737) 5273 -> Saved to SQL Table
# (738) 9409096 -> Saved to SQL Table
# (739) 4444504 -> Saved to SQL Table
# (740) 5302 -> Saved to SQL Table
# (741) 819430 -> Saved to SQL Table
# (742) 5253 -> Saved to SQL Table
# (743) 54661 -> Saved to SQL Table
# (744) 187438 -> Saved to SQL Table
# (745) 5308 -> Saved to SQL Table
# (746) 54912 -> Saved to SQL Table
# (747) 5796 -> Saved to SQL Table
# (748) 5283 -> Saved to SQL Table
#
# (749) No new entires to add to the SQL Table.
# (750) 35632 -> Saved to SQL Table
#
# (751) No new entires to add to the SQL Table.
#
# (752) No new entires to add to the SQL Table.
# (753) 17290424 -> Saved to SQL Table
# (754) 4588590 -> Saved to SQL Table
#
# (755) No new entires to add to the SQL Table.
#
# (756) No new entires to add to the SQL Table.
# (757) 13835630 -> Saved to SQL Table
# (758) 3144 -> Saved to SQL Table
# (759) 2241 -> Saved to SQL Table
#
# (760) No new entires to add to the SQL Table.
#
# (761) No new entires to add to the SQL Table.
# (762) 5374 -> Saved to SQL Table
#
# (763) No new entires to add to the SQL Table.
#
# (764) No new entires to add to the SQL Table.
# (765) 16736478 -> Saved to SQL Table
# (766) 5293389 -> Saved to SQL Table
# (767) 9693858 -> Saved to SQL Table
# (768) 5375 -> Saved to SQL Table
#
# (769) No new entires to add to the SQL Table.
#
# (770) No new entires to add to the SQL Table.
#
# (771) No new entires to add to the SQL Table.
#
# (772) No new entires to add to the SQL Table.
# (773) 4470755 -> Saved to SQL Table
#
# (774) No new entires to add to the SQL Table.
#
# (775) No new entires to add to the SQL Table.
# (776) 99300 -> Saved to SQL Table
# (777) 5391 -> Saved to SQL Table
# (778) 28536134 -> Saved to SQL Table
# (779) 36358 -> Saved to SQL Table
# (780) 5807 -> Saved to SQL Table
#
# (781) No new entires to add to the SQL Table.
# (782) 422589 -> Saved to SQL Table
#
# (783) No new entires to add to the SQL Table.
#
# (784) No new entires to add to the SQL Table.
# (785) 5293518 -> Saved to SQL Table
#
# (786) No new entires to add to the SQL Table.
# (787) 8141643 -> Saved to SQL Table
#
# (788) No new entires to add to the SQL Table.
# (789) 22427 -> Saved to SQL Table
# (790) 8252668 -> Saved to SQL Table
#
# (791) No new entires to add to the SQL Table.
# (792) 54531 -> Saved to SQL Table
#
# (793) No new entires to add to the SQL Table.
# (794) 3175 -> Saved to SQL Table
#
# (795) No new entires to add to the SQL Table.
#
# (796) No new entires to add to the SQL Table.
#
# (797) No new entires to add to the SQL Table.
#
# (798) No new entires to add to the SQL Table.
#
# (799) No new entires to add to the SQL Table.
# (800) 8001032 -> Saved to SQL Table
#
# (801) No new entires to add to the SQL Table.
#
# (802) No new entires to add to the SQL Table.
# (803) 34635 -> Saved to SQL Table
#
# (804) No new entires to add to the SQL Table.
#
# (805) No new entires to add to the SQL Table.
# (806) 35013015 -> Saved to SQL Table
#
# (807) No new entires to add to the SQL Table.
# (808) 54669 -> Saved to SQL Table
#
# (809) No new entires to add to the SQL Table.
# (810) 559126 -> Saved to SQL Table
# (811) 4589364 -> Saved to SQL Table

# %%
conn = create_connection("CSdb.db")
df = pd.read_sql('''SELECT * FROM CStable''',conn)
# Out:
# sqlite3 version: 2.6.0
# ==============

# %%
df.iloc[1157,5] = 'COCCOC(=O)N[C@H](C(=O)NCCCCCCCOP(=O)(O)C)CCCCNC(=O)OCCOC COCCO/C(=N/CCCC[C@@H](/C(=N/CCCCCCCOP(=O)(C)O)/O)/N=C(\O)/OCCOC)/O'

# %%
df
# Out:
#       ChemSpider_ID                                       InChI_string  \
# 0               103  InChI=1S/C3H5O7P/c4-2(3(5)6)1-10-11(7,8)9/h1H2...
# 1               134  InChI=1S/C5H9NO3/c6-3-4(7)1-2-5(8)9/h1-3,6H2,(...
# 2               140  InChI=1S/C20H23N7O7/c21-20-25-16-15(18(32)26-2...
# 3               185  InChI=1S/C5H5N5/c6-4-3-5(9-1-7-3)10-2-8-4/h1-2...
# 4               235            InChI=1S/C7H6O/c8-6-7-4-2-1-3-5-7/h1-6H
# 5               292  InChI=1S/C11H12Cl2N2O5/c12-10(13)11(18)14-8(5-...
# 6               299  InChI=1S/C5H14NO/c1-6(2,3)4-5-7/h7H,4-5H2,1-3H...
# 7               431  InChI=1S/C13H18ClNO/c1-9(15-13(2,3)4)12(16)10-...
# 8               566  InChI=1S/C4H9N3O2/c1-7(4(5)6)2-3(8)9/h2H2,1H3,...
# 9               659                    InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
# 10              661  InChI=1S/C8H11NO2/c9-4-3-6-1-2-7(10)8(11)5-6/h...
# 11              733           InChI=1S/C3H8O3/c4-1-3(6)2-5/h3-6H,1-2H2
# 12              764       InChI=1S/C6H6O2/c7-5-1-2-6(8)4-3-5/h1-4,7-8H
# 13              815  InChI=1S/C9H13NO3/c1-10-5-9(13)6-2-3-7(11)8(12...
# 14              911  InChI=1S/C6H6N2O/c7-6(9)5-2-1-3-8-4-5/h1-4H,(H...
# 15              913  InChI=1S/C6H5NO2/c8-6(9)5-2-1-3-7-4-5/h1-4H,(H...
# 16              917  InChI=1S/C10H14N2/c1-12-7-3-5-10(12)9-4-2-6-11...
# 17              937                                  InChI=1S/H2O/h1H2
# 18              979            InChI=1S/H3O4P/c1-5(2,3)4/h(H3,1,2,3,4)
# 19              989  InChI=1S/C5H14NO4P/c1-6(2,3)4-5-10-11(7,8)9/h4...
# 20             1017  InChI=1S/C5H5N3O/c6-5(9)4-3-7-1-2-8-4/h1-3H,(H...
# 21             1020                InChI=1S/C5H5N/c1-2-4-6-5-3-1/h1-5H
# 22             1032        InChI=1S/H3O4P/c1-5(2,3)4/h(H3,1,2,3,4)/p-3
# 23             1042  InChI=1S/C20H30O/c1-16(8-6-9-17(2)13-15-21)11-...
# 24             1085        InChI=1S/H2O4S/c1-5(2,3)4/h(H2,1,2,3,4)/p-2
# 25             1141  InChI=1S/C4H4N2O2/c7-3-1-2-5-4(8)6-3/h1-2H,(H2...
# 26             1143               InChI=1S/CH4N2O/c2-1(3)4/h(H4,2,3,4)
# 27             1169  InChI=1S/C10H15N/c1-9(11-2)8-10-6-4-3-5-7-10/h...
# 28             1262  InChI=1S/C14H14O3/c1-9(14(15)16)10-3-4-12-8-13...
# 1167  YTJNAKHNWDZIDNRVJPWXAWSA-N      C33H42N4O6S2       654.840
# 1168  JJMUFECOTFOXFSYAHNSOBISA-N        C33H44N4O6       592.726
# 1169  ACVYKQPHJKFJQJQNRGTSIVSA-N       C33H42N4O6S       622.775
# 1170  FZOAUUAPVGVNIZFZJUOLLLSA-N        C33H42N4O6       590.710
# 1171  KZHGVSJOKHIYKSXYNCPAPSSA-N       C33H42N4O6S       622.775
# 1172  IVJOITVXYMZPEVYQIBVIRQSA-N        C22H24N2O8       444.435
# 1173  KRMYTEJZPOLDJAFZJUOLLLSA-N        C33H44N4O6       592.726
# 1174  YRKNPFVJGRPAROXWDZYTQJSA-N        C22H24N2O8       444.435
# 1175  AVYQBBPGKJDTCXOVXGELPFSA-N        C22H28N2O8       448.466
# 1176  PNPMSIBCHAIGPDXYNCPAPSSA-N       C33H44N4O6S       624.791
# 1177  GYWVHRWEMNFGHPMQTDQSPWSA-N       C33H44N4O6S       624.791
# 1178  SUOGCJXKZAMSEIBFUHXYTFSA-N        C22H26N2O8       446.450
# 1179  IVJOITVXYMZPEVMJCMRAJCSA-N        C22H24N2O8       444.435
# 1180  BYSJBGGTNVKPEACRZONSFXSA-N        C22H26N2O8       446.450
# 1181  NDAMFCVFKSFMQPVBEVLBHNSA-N       C33H46N4O6S       626.807
# 1182  PNPMSIBCHAIGPDIBIRVQFOSA-N       C33H44N4O6S       624.791
# 1183  UCZQDGSRJPTKGZUJHLUPGYSA-N       C33H44N4O6S       624.791
# 1184  WRUDTZAASVCWATCWDCEQMOSA-N     C24H25ClFN5O3       485.938
# 1185  WDENQIQQYWYTPOUHFFFAOYSA-N        C26H23N7O2       465.507
# 1186  UFNVPOGXISZXJDFXYLGSAYSA-N        C40H59NO11       729.897
# 1187  RLAWWYSOJDYHDCABHNRTSZSA-N        C21H31N3O5       405.488
#
#                                                  SMILES  \
# 0                              C(C(=O)C(=O)O)OP(=O)(O)O
# 1                                     C(CC(=O)O)C(=O)CN
# 2     c1cc(ccc1C(=O)NC(CCC(=O)O)C(=O)O)NCC2CNc3c(c(=...
# 3                                  c1[nH]c(c-2ncnc2n1)N
# 4                                         c1ccc(cc1)C=O
# 5          c1cc(ccc1C(C(CO)NC(=O)C(Cl)Cl)O)[N+](=O)[O-]
# 6                                        C[N+](C)(C)CCO
# 7                        CC(C(=O)c1cccc(c1)Cl)NC(C)(C)C
# 8                                     CN(CC(=O)O)C(=N)N
# 9                                               CS(=O)C
# 10                                    c1cc(c(cc1CCN)O)O
# 11                                           C(C(CO)O)O
# 12                                         c1cc(ccc1O)O
# 13                                CNCC(c1ccc(c(c1)O)O)O
# 14                                     c1cc(cnc1)C(=O)N
# 15                                     c1cc(cnc1)C(=O)O
# 16                                     CN1CCCC1c2cccnc2
# 17                                                    O
# 18                                           OP(=O)(O)O
# 19                              C[N+](C)(C)CCOP(=O)(O)O
# 20                                     c1cnc(cn1)C(=O)N
# 21                                             c1ccncc1
# 22                                  [O-]P(=O)([O-])[O-]
# 23               CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CCO)C)C
# 24                                    [O-]S(=O)(=O)[O-]
# 1185  CC#CC(=O)N1CCCC1c2nc(c3n2ccnc3N)c4ccc(cc4)C(=O...
# 1186  C[C@@H]1C[C@@H]2CC[C@H]3C(=C)C[C@@H](O3)CC[C@]...
# 1187  c1ccc(cc1)CCC(C(=O)O)NC(CCCCN)C(=O)N2CCC[C@H]2...
#
#                                             Common_Name  \
# 0                      HPV / 3-Phosphonooxypyruvic acid
# 1                                   Aminolevulinic Acid
# 2                             Leucovorin / folinic acid
# 3                                         ADE / Adenine
# 4                                          Benzaldehyde
# 5     CAF / 2,2-Dichloro-N-[1,3-dihydroxy-1-(4-nitro...
# 6                                               Choline
# 7                                Wellbutrin / bupropion
# 8                                              Creatine
# 9                        Sclerosol / Dimethyl sulfoxide
# 10                                             Dopamine
# 11                                  Glycerol / glycerin
# 12                                         Hydroquinone
# 13                              Epinephrin / adrenaline
# 14                                         Nicotinamide
# 15                                     Niaspan / Niacin
# 16                              Nicoderm / (±)-nicotine
# 17                                          ICE / Water
# 18                     Phosphoricacid / Phosphoric acid
# 19                 CHOP / Phosphocholine conjugate acid
# 20                                         Pyrazinamide
# 21                                             Pyridine
# 22                       Phosphate / Phosphate trianion
# 23                                              Retinol
# 24                           Sulphate / Sulfate dianion
# 25                                               Uracil
# 26                                                 Urea
# 27                  Methamphetamine / (±)-Metamfetamine
# 28                                             Naproxen
# 29             3,4-Methylenedioxymethamphetamine / MDMA
# ...                                                 ...
# 1158                                        glecaprevir
# 1159                          Calquence / acalabrutinib
# 1160                                         Enasidenib
# 1161                                         Ivosidenib
# 1162  Epoetin Alfa / (4R,5S,6S,7R,9R,10R,11Z,13Z,16R...
# 1163                 Ibritumomab Tiuxetan / Ibritumomab
# 1164  Natalizumab / (2S,5S,8S,11R,14S,17S,20S,23S,26...
# 1165  Cholestyramine / (Z)-1-(Chol-2-en-3-yl)-2-phen...
# 1166  PEB / 3-[2-[(Z)-[3-(2-carboxyethyl)-4-methyl-5...
# 1167  PEB / 3-[(2Z)-2-[[3-(2-carboxyethyl)-4-methyl-...
# 1168  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(3...
# 1169  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[[4...
# 1170  PEB / 3-[2-[[3-(2-carboxyethyl)-5-[(Z)-(3-ethy...
# 1171  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z...
# 1172  TAC / (2S,4aS,5aS,6S,12aS)-4-(Dimethylamino)-3...
# 1173  PEB / 3-[2-[[3-(2-carboxyethyl)-5-[(Z)-(3-ethy...
# 1174  TAC / (2R,4S,4aS,5aS,6S,12aS)-4-(Dimethylamino...
# 1175  TAC / (1S,4S,4aS,5aS,6S,12S,12aS)-4-(Dimethyla...
# 1176  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z...
# 1177  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z...
# 1178  TAC / (4aS,5aS,6S,12S,12aS)-4-(Dimethylamino)-...
# 1179  TAC / (2S,4aS,5aS,6S,12aS)-4-(Dimethylamino)-3...
# 1180  TAC / (1S,4S,4aS,5aS,6S,12aR)-4-(Dimethylamino...
# 1181  PEB / 3-[2-[[3-(2-carboxyethyl)-5-[(4-ethyl-3-...
# 1182  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z...
# 1183  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(3...
# 1184                                           Afatinib
# 1185                                      Acalabrutinib
# 1186                                           Eribulin
# 1187  Zestril / N2-(1-Carboxy-3-phenylpropyl)lysyl-L...
#
#                                         Systematic_Name   logP  H_Bond_Donors  \
# 0                  2-Oxo-3-(phosphonooxy)propanoic acid  -2.91              3
# 1                           5-Amino-4-oxopentanoic acid  -0.93              3
# 2     N-(4-{[(2-Amino-5-formyl-4-oxo-1,4,5,6,7,8-hex...  -3.19              8
# 3                                      1H-Purin-6-amine  -2.12              3
# 4                                          Benzaldehyde   1.64              0
# 5     2,2-Dichloro-N-[1,3-dihydroxy-1-(4-nitrophenyl...   1.02              3
# 6                 2-Hydroxy-N,N,N-trimethylethanaminium  -3.70              1
# 7     1-(3-Chlorophenyl)-2-[(2-methyl-2-propanyl)ami...   3.47              1
# 8                       N-Carbamimidoyl-N-methylglycine  -1.88              4
# 9                               (Methylsulfinyl)methane  -1.35              0
# 10                     4-(2-Aminoethyl)-1,2-benzenediol   0.12              4
# 11                                             Glycerol  -2.32              3
# 12                                         Hydroquinone   0.64              2
# 13    4-[1-Hydroxy-2-(methylamino)ethyl]-1,2-benzene...  -0.63              4
# 14                                         Nicotinamide  -0.11              2
# 15                                       Nicotinic acid   0.15              1
# 16                  3-(1-Methyl-2-pyrrolidinyl)pyridine   0.72              0
# 17                                                Water  -1.38              2
# 18                                      Phosphoric acid  -2.15              3
# 19         N,N,N-Trimethyl-2-(phosphonooxy)ethanaminium  -4.99              2
# 20                                2-Pyrazinecarboxamide  -0.37              2
# 21                                             Pyridine   0.73              0
# 22                                            Phosphate  -2.15              3
# 23                                              Retinol   6.84              1
# 24                                              Sulfate  -1.03              2
# 25                           2,4(1H,3H)-Pyrimidinedione  -0.71              2
# 26                                                 Urea  -2.11              4
# 27                      N-Methyl-1-phenyl-2-propanamine   1.94              1
# 28               2-(6-Methoxy-2-naphthyl)propanoic acid   3.00              1
# 29      1-(1,3-Benzodioxol-5-yl)-N-methyl-2-propanamine   1.81              1
# ...                                                 ...    ...            ...
# 1158  (1R,14E,18R,22R,26S,29S)-N-[(1R,2R)-2-(Difluor...   1.71              3
# 1159  4-{8-Amino-3-[(2S)-1-(2-butynoyl)-2-pyrrolidin...   0.77              3
# 1160  2-Methyl-1-[(4-[6-(trifluoromethyl)-2-pyridiny...   4.24              3
# 1161  N-{(1S)-1-(2-Chlorophenyl)-2-[(3,3-difluorocyc...   0.38              1
# 1162  (4R,5S,6S,7R,9R,10R,11Z,13Z,16R)-10-{[(2R,4R,5...   2.44              7
# 1163  N-[(2S)-2-[Bis(carboxymethyl)amino]-3-(4-{[hyd...   1.76              7
# 1164  (2S,5S,8S,11R,14S,17S,20S,23S,26S,29S,32S)-17-...   5.86             19
# 1165          (Z)-1-(Chol-2-en-3-yl)-2-phenylethenamine  11.65              2
# 1166  3-[2-[(Z)-[3-(2-carboxyethyl)-4-methyl-5-[[4-m...   1.10              5
# 1167  3-[(2Z)-2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z)...   2.61              6
# 1168  3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(3-methy...   1.38              6
# 1169  3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[[4-methy...   1.04              5
# 1170  3-[2-[[3-(2-carboxyethyl)-5-[(Z)-(3-ethyl-4-me...   2.99              6
# 1171  3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z)-[4-m...   2.89              6
# 1172  (2S,4aS,5aS,6S,12aS)-4-(Dimethylamino)-3,6,10,...   3.09              7
# 1173  3-[2-[[3-(2-carboxyethyl)-5-[(Z)-(3-ethyl-4-me...   3.42              6
# 1174  (2R,4S,4aS,5aS,6S,12aS)-4-(Dimethylamino)-6,10...   0.49              6
# 1175  (1S,4S,4aS,5aS,6S,12S,12aS)-4-(Dimethylamino)-...   0.36              9
# 1176  3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z)-[4-m...   3.32              6
# 1177  3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z)-[4-m...   3.15              6
# 1178  (4aS,5aS,6S,12S,12aS)-4-(Dimethylamino)-1,3,6,...   3.51              9
# 1179  (2S,4aS,5aS,6S,12aS)-4-(Dimethylamino)-3,6,10,...   3.09              7
# 1180  (1S,4S,4aS,5aS,6S,12aR)-4-(Dimethylamino)-1,3,...  -0.33              8
# 1181  3-[2-[[3-(2-carboxyethyl)-5-[(4-ethyl-3-methyl...   1.62              6
# 1182  3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z)-[4-m...   3.32              6
# 1183  3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(3-methy...   1.19              6
# 1184  (2E)-N-{4-[(3-Chloro-4-fluorophenyl)amino]-6-[...   3.59              2
# 1185  4-{8-Amino-3-[(2S)-1-(2-butynoyl)-2-pyrrolidin...   0.77              3
# 1186  (3R,6S,9S,12S,14R,18S,20R,21R,22S,26R,29S,31R,...   3.88              3
# 1187     N~2~-(1-Carboxy-3-phenylpropyl)lysyl-L-proline   1.19              5
#
#       H_Bond_Acceptors  Num_Rota_Bonds  Lipinski_Rule_5 Polar_Surface_Area  \
# 0                    7               4                0             131 Å2
# 1                    4               4                0              80 Å2
# 2                   14               9                2             216 Å2
# 3                    5               0                0              75 Å2
# 4                    1               1                0              17 Å2
# 5                    7               6                0             115 Å2
# 6                    2               2                0              20 Å2
# 7                    2               4                0              29 Å2
# 8                    5               3                0              90 Å2
# 9                    1               0                0              36 Å2
# 10                   3               2                0              66 Å2
# 11                   3               2                0              61 Å2
# 12                   2               0                0              40 Å2
# 13                   4               3                0              73 Å2
# 14                   3               1                0              56 Å2
# 15                   3               1                0              50 Å2
# 16                   2               1                0              16 Å2
# 17                   1               0                0               0 Å2
# 18                   4               0                0              88 Å2
# 19                   5               4                0              77 Å2
# 20                   4               1                0              69 Å2
# 21                   1               0                0              13 Å2
# 22                   4               0                0              96 Å2
# 23                   1               5                1              20 Å2
# 24                   4               0                0              89 Å2
# 25                   4               0                0              58 Å2
# 26                   3               0                0              69 Å2
# 27                   1               3                0              12 Å2
# 28                   3               3                0              47 Å2
# 29                   3               3                0              30 Å2
# ...                ...             ...              ...                ...
# 1158                15               7                2             204 Å2
# 1159                 9               5                0             119 Å2
# 1160                 8               8                0             109 Å2
# 1161                 9               8                1             119 Å2
# 1162                17              10                3             236 Å2
# 1163                16              20                3             241 Å2
# 1164                30              41                4             543 Å2
# 1165                 1               5                1              26 Å2
# 1166                10              12                3             239 Å2
# 1167                10              11                3             238 Å2
# 1168                10              14                3             164 Å2
# 1169                10              14                3             204 Å2
# 1170                10              13                3             164 Å2
# 1171                10              13                3             203 Å2
# 1172                10               2                2             182 Å2
# 1173                10              13                3             164 Å2
# 1174                10               2                2             178 Å2
# 1175                10               2                2             188 Å2
# 1176                10              13                3             203 Å2
# 1177                10              12                3             203 Å2
# 1178                10               2                2             188 Å2
# 1179                10               2                2             182 Å2
# 1180                10               2                2             185 Å2
# 1181                10              14                3             203 Å2
# 1182                10              13                3             203 Å2
# 1183                10              14                3             203 Å2
# 1184                 8               8                0              89 Å2
# 1185                 9               5                0             119 Å2
# 1186                12               4                2             146 Å2
# 1187                 8              12                1             133 Å2
#
#           Enthalpy_Vap        Density               Boiling_Point
# 0      75.5±6.0 kJ/mol  1.9±0.1 g/cm3   432.4±47.0 °C at 760 mmHg
# 1      59.2±6.0 kJ/mol  1.2±0.1 g/cm3   298.4±20.0 °C at 760 mmHg
# 2                       1.7±0.1 g/cm3
# 3      48.0±3.0 kJ/mol  1.9±0.1 g/cm3   243.2±50.0 °C at 760 mmHg
# 4      41.5±3.0 kJ/mol  1.0±0.1 g/cm3    178.7±0.0 °C at 760 mmHg
# 5     100.0±3.0 kJ/mol  1.5±0.1 g/cm3   644.9±55.0 °C at 760 mmHg
# 6
# 7      57.8±3.0 kJ/mol  1.1±0.1 g/cm3   334.8±27.0 °C at 760 mmHg
# 8      56.1±6.0 kJ/mol  1.4±0.1 g/cm3   271.6±42.0 °C at 760 mmHg
# 9      40.8±3.0 kJ/mol  1.1±0.1 g/cm3    189.0±9.0 °C at 760 mmHg
# 10     60.4±3.0 kJ/mol  1.2±0.1 g/cm3   337.7±27.0 °C at 760 mmHg
# 11     61.4±6.0 kJ/mol  1.3±0.1 g/cm3    290.0±0.0 °C at 760 mmHg
# 12     54.6±3.0 kJ/mol  1.3±0.1 g/cm3    286.0±0.0 °C at 760 mmHg
# 13     70.2±3.0 kJ/mol  1.3±0.1 g/cm3   413.1±40.0 °C at 760 mmHg
# 14     57.7±3.0 kJ/mol  1.2±0.1 g/cm3   334.4±15.0 °C at 760 mmHg
# 15     56.2±3.0 kJ/mol  1.3±0.1 g/cm3   292.5±13.0 °C at 760 mmHg
# 16     48.2±3.0 kJ/mol  1.0±0.1 g/cm3   244.4±28.0 °C at 760 mmHg
# 17     40.7±0.0 kJ/mol  1.0±0.1 g/cm3    100.0±9.0 °C at 760 mmHg
# 18                      2.2±0.1 g/cm3    158.0±0.0 °C at 760 mmHg
# 19
# 20     60.3±3.0 kJ/mol  1.3±0.1 g/cm3   357.4±22.0 °C at 760 mmHg
# 21     35.1±0.0 kJ/mol  1.0±0.1 g/cm3    115.3±0.0 °C at 760 mmHg
# 22                                       158.0±0.0 °C at 760 mmHg
# 23     78.0±6.0 kJ/mol  1.0±0.1 g/cm3   421.2±14.0 °C at 760 mmHg
# 24     62.9±6.0 kJ/mol                  330.0±11.0 °C at 760 mmHg
# 25                      1.3±0.1 g/cm3
# 26     43.3±3.0 kJ/mol  1.2±0.1 g/cm3   196.6±23.0 °C at 760 mmHg
# 27     45.2±3.0 kJ/mol  0.9±0.1 g/cm3    215.5±9.0 °C at 760 mmHg
# 28     69.1±3.0 kJ/mol  1.2±0.1 g/cm3   403.9±20.0 °C at 760 mmHg
    cnt_nitr = 0
    for i in smile:
        if i.lower() == 'o':
            cnt_oxy+=1
        elif i.lower() == 'n':
            cnt_nitr +=1
    dictNO = {'O':cnt_oxy,'N':cnt_nitr}
    return dictNO

cntNO(smi)['O']
# Out:
# 7

# %%
def extrNum(item):
    '''extract just the number from PSA value'''
    try:
        return int(re.match('\d{1,}',item).group(0))
    except (AttributeError,TypeError) as e:
        return None
    
def lipinski5(row):
    '''return how many violations of the lipinski rule of 5'''
    lipinskiViolation=0
    if row['H_Bond_Donors'] > 5:
        lipinskiViolation+=1
    if row['H_Bond_Acceptors'] > 10:
        lipinskiViolation+=1
    if row['Average_Mass'] > 500:
        lipinskiViolation+=1
    if row['logP'] > 5:
        lipinskiViolation+=1
    return lipinskiViolation

def veberule(row):
    '''return how many violations of the veber rule of 2'''
    veberViolation = 0
    if row['Num_Rota_Bonds'] > 10:
        veberViolation+=1
    if row['Polar_Surface_Area'] >140:
        veberViolation+=1
    return veberViolation

def cntArom(smile):
    arom_count = 0
    mol = pybel.readstring('smi',smile)
    for rings in mol.OBMol.GetSSSR():
        ring_dat = [rings.Size(),rings.IsAromatic(),rings.GetType()]
        if ring_dat[1]: #if is aromatic ring
            arom_count+=1
    return arom_count

###NO NEED TO CALC LIPINSKI RULE OF 5 VIOLATION SINCE ALREADY SCRAPPED FROM CHEMSPIDER
#lip5vio=[] 
#for i,row in df.iterrows():
#    lip5vio.append(lipinski5(row))

# %%
acalabrutinib = 'CC#CC(=O)N1CCCC1c2nc(c3n2ccnc3N)c4ccc(cc4)C(=O)Nc5ccccn5'
smi = pybel.readstring('smi',acalabrutinib)
ss=pybel.Smarts('c:c')
ss.findall(smi)

# %%
furan = 'c1ccoc1'
smi = pybel.readstring('smi',furan)
f=pybel.Smarts('c:c:c:o:c')
f.findall(smi)
# Out:
# [(1, 2, 3, 4, 5)]

# %%
ff =pybel.Smarts('[a]@[a]@[a]@[a]@[a]')
ff.findall(smi)
# Out:
# [(1, 5, 4, 3, 2)]

# %%
st = pybel.Smarts('[$([cX3](:*):*)]')
st.findall(smi)

# %%
mol = openbabel.OBMol()
openbabel.OBConversion().ReadString(mol, acalabrutinib)
# for neighbour_atom in openbabel.OBAtomAtomIter(mol):
#     print(neighbour_atom.GetAtomicNum())
#     bond = mol.GetBond(neighbour_atom)
#     print(bond.GetBondOrder())
openbabel.OBAtom(mol)

# %%
import webScrapeNPASSnCS
indigo = Indigo()
#driver = webdriver.Firefox(executable_path=r'C:/Program Files/Mozilla Firefox/geckoDriver/geckodriver.exe')
dff = df.merge(df.SMILES.apply(lambda s: pd.Series({'Num_Nitrogens':cntNO(s)['N'], 
                                              'Num_Oxygens':cntNO(s)['O'],
                                              'Stereocenters':indigo.loadMolecule(s).countStereocenters(),
                                              'SSSR':indigo.loadMolecule(s).countSSSR(),
                                              'Arom_rings':cntArom(s)} ) ),
         left_index=True, right_index=True)

#dff['Lipinski5_violations'] = lip5vio
dff['Polar_Surface_Area'] = dff.Polar_Surface_Area.apply(lambda s: extrNum(s))
dff['is_NP'] = dff.Common_Name.apply(lambda s: 'NP' if webScrapeNPASSnCS.dblNameSelenNpass(s,driver) else 'non-NP')
veber_viol = []
for i,row in dff.iterrows():
    veber_viol.append(veberule(row))
dff['Veber_Violations'] = veber_viol
# Out:
# 0 matches were found
# HPV was not found in NPASS DB
# 0 matches were found
# 3-Phosphonooxypyruvic acid was not found in NPASS DB
# 1 matches were found
# 1 matches were found
# 2844 matches were found
# 95 matches were found
# 83 matches were found
# 18 matches were found
# 0 matches were found
# 0 matches were found
# Wellbutrin was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# bupropion was not found in NPASS DB
# 1 matches were found
# 0 matches were found
# 0 matches were found
# Sclerosol was not found in NPASS DB
# 1 matches were found
# 2 matches were found
# 51 matches were found
# 22 matches were found
# 5 matches were found
# 2 matches were found
# 0 matches were found
# 0 matches were found
# Niaspan was not found in NPASS DB
# 2 matches were found
# 0 matches were found
# 0 matches were found
# Nicoderm was not found in NPASS DB
# 30926 matches were found
# 989 matches were found
# 0 matches were found
# 0 matches were found
# Phosphoricacid was not found in NPASS DB
# 7 matches were found
# 5 matches were found
# 0 matches were found
# Pyrazinamide was not found in NPASS DB
# 118 matches were found
# 134 matches were found
# 1 matches were found
# 0 matches were found
# Sulphate was not found in NPASS DB
# 0 matches were found
# Sulfate dianion was not found in NPASS DB
# 3 matches were found
# 31 matches were found
# 0 matches were found
# Methamphetamine was not found in NPASS DB
# 30926 matches were found
# 1 matches were found
# 0 matches were found
# 0 matches were found
# 3,4-Methylenedioxymethamphetamine was not found in NPASS DB
# 0 matches were found
# MDMA was not found in NPASS DB
# 0 matches were found
# Doxil was not found in NPASS DB
# 0 matches were found
# 3-Glycoloyl-3,5,12-trihydroxy-10-methoxy-6,11-dioxo-1,2,3,4,6,11-hexahydro-1-tetracenyl 3-amino-2,3,6-trideoxyhexopyranoside was not found in NPASS DB
# 1 matches were found
# 0 matches were found
# Phenytoin was not found in NPASS DB
# 0 matches were found
# Vidaza was not found in NPASS DB
# 0 matches were found
# 4-Amino-1-pentofuranosyl-1,3,5-triazin-2(1H)-one was not found in NPASS DB
# 3 matches were found
# 0 matches were found
# Diamox was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# acetazolamide was not found in NPASS DB
# 0 matches were found
# Methacholine was not found in NPASS DB
# 0 matches were found
# Zovirax was not found in NPASS DB
# 0 matches were found
# Aciclovir was not found in NPASS DB
# 1 matches were found
# 0 matches were found
# Ventolin was not found in NPASS DB
# 0 matches were found
# Salbutamol was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Fosamax was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# alendronic acid was not found in NPASS DB
# 0 matches were found
# Zyloprim was not found in NPASS DB
# 1 matches were found
# 0 matches were found
# alosetron was not found in NPASS DB
# 0 matches were found
# Xanax was not found in NPASS DB
# 0 matches were found
# Alprazolam was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Iothalamate was not found in NPASS DB
# 0 matches were found
# Diatrizoic acid was not found in NPASS DB
# 0 matches were found
# Ethyol was not found in NPASS DB
# 0 matches were found
# Amifostine was not found in NPASS DB
# 1 matches were found
# 0 matches were found
# Pacerone was not found in NPASS DB
# 0 matches were found
# Amiodarone was not found in NPASS DB
# 0 matches were found
# Elavil was not found in NPASS DB
# 0 matches were found
# Amitriptyline was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Norvasc was not found in NPASS DB
# 0 matches were found
# Amlodipine was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Arimidex was not found in NPASS DB
# 0 matches were found
# Anastrozole was not found in NPASS DB
# 1 matches were found
# 0 matches were found
# Tenormin was not found in NPASS DB
# 0 matches were found
# DL-Atenolol was not found in NPASS DB
# 0 matches were found
# Imuran was not found in NPASS DB
# 0 matches were found
# 0 matches were found
#
# Linaclotide was not found in NPASS DB
# 0 matches were found
# Ivacaftor was not found in NPASS DB
# 0 matches were found
# Cotellic was not found in NPASS DB
# 0 matches were found
# Cobimetinib was not found in NPASS DB
# 0 matches were found
# Lumacaftor was not found in NPASS DB
# 0 matches were found
# Dostinex was not found in NPASS DB
# 30926 matches were found
# 0 matches were found
# Ulipristal was not found in NPASS DB
# 0 matches were found
# Tiotropium was not found in NPASS DB
# 0 matches were found
# (1R,2R,4S,5S,7s)-7-[2-Hydroxy(di-2-thienyl)acetoxy]-9,9-dimethyl-3-oxa-9-azoniatricyclo[3.3.1.02,4]nonane was not found in NPASS DB
# 0 matches were found
# Eltrombopag was not found in NPASS DB
# 1 matches were found
# 0 matches were found
# Ixempra was not found in NPASS DB
# 0 matches were found
# Ixabepilone was not found in NPASS DB
# 2 matches were found
# 0 matches were found
# 2C-T-7 was not found in NPASS DB
# 0 matches were found
# TJG366J9BA was not found in NPASS DB
# 0 matches were found
# Eltrombopag was not found in NPASS DB
# 0 matches were found
# Everolimus was not found in NPASS DB
# 0 matches were found
# Elidel was not found in NPASS DB
# 0 matches were found
# Pimecrolimus was not found in NPASS DB
# 0 matches were found
# Clindamycin was not found in NPASS DB
# 0 matches were found
# Vidaza was not found in NPASS DB
# 30926 matches were found
# 0 matches were found
# Nitrostat was not found in NPASS DB
# 0 matches were found
# 3-(Nitrooxy)-2-[(nitrooxy)methyl]propyl nitrate was not found in NPASS DB
# 0 matches were found
# Prasugrel was not found in NPASS DB
# 0 matches were found
# (S)-Prasugrel was not found in NPASS DB
# 0 matches were found
# Florbetaben was not found in NPASS DB
# 0 matches were found
# Torisel was not found in NPASS DB
# 0 matches were found
# Temsirolimus was not found in NPASS DB
# 1 matches were found
# 0 matches were found
# Moxidectin was not found in NPASS DB
# 2 matches were found
# 0 matches were found
# Deutetrabenazine was not found in NPASS DB
# 0 matches were found
# (+)-tetrabenazine was not found in NPASS DB
# 0 matches were found
# Collagenase was not found in NPASS DB
# 0 matches were found
# (1S,3aS,5aS,8aS,8bS,10aR,11S,13aS,15aS,18aS,18bS,20aR)-3a,5a,8a,8b,10a,13a,15a,18a,18b,20a-decamethyl-1,11-dioctyl-1,2,3,3a,3b,4,5,5a,6,8,8a,8b,9,10,10a,11,12,13,13a,13b,14,15,15a,16,18,18a,18b,19,20,20a-triacontahydrobiscyclopenta[5,6]naphtho[1,2-b:1',2'-i]phenazine was not found in NPASS DB
# 0 matches were found
# Nilstat was not found in NPASS DB
# 30926 matches were found
# 0 matches were found
# Simeprevir was not found in NPASS DB
# 0 matches were found
# Vismodegib was not found in NPASS DB
# 15 matches were found
# 0 matches were found
# Olaparib was not found in NPASS DB
# 0 matches were found
# Onglyza was not found in NPASS DB
# 0 matches were found
# (1S,3S,5S)-2-{(2S)-2-Amino-2-[3-(hydroxymethyl)adamantan-1-yl]acetyl}-2-azabicyclo[3.1.0]hexane-3-carbonitrile was not found in NPASS DB
# 0 matches were found
# Niraparib was not found in NPASS DB
# 0 matches were found
# Daclatasvir was not found in NPASS DB
# 0 matches were found
# Suvorexant was not found in NPASS DB
# 0 matches were found
# Sancuso was not found in NPASS DB
# 0 matches were found
# 1-Methyl-N-[(3-exo)-9-methyl-9-azabicyclo[3.3.1]non-3-yl]-1H-indazole-3-carboxamide was not found in NPASS DB
# 0 matches were found
# Halaven was not found in NPASS DB
# 0 matches were found
# Eribulin was not found in NPASS DB
# 0 matches were found
# Zelboraf was not found in NPASS DB
# 0 matches were found
# Vemurafenib was not found in NPASS DB
# 0 matches were found
# Iclusig was not found in NPASS DB
# 0 matches were found
# Ponatinib was not found in NPASS DB
# 0 matches were found
# Ruxolitinib was not found in NPASS DB
# 0 matches were found
# Sonidegib was not found in NPASS DB
# 0 matches were found
# Ixazomib was not found in NPASS DB
# 0 matches were found
# Istodax was not found in NPASS DB
# 0 matches were found
# (3S,6Z,9S,12R,16S)-6-Ethylidene-3,12-diisopropyl-16-[(1E)-4-sulfanyl-1-buten-1-yl]-9-(sulfanylmethyl)-1-oxa-4,7,10-triazacyclohexadecane-2,5,8,11,14-pentone was not found in NPASS DB
# 0 matches were found
# Dolutegravir was not found in NPASS DB
# 0 matches were found
# Copanlisib was not found in NPASS DB
# 0 matches were found
# Goserelin Acetate was not found in NPASS DB
# 0 matches were found
# 5-Oxoprolyl-L-histidyl-N-[(1S,4S,7S,10S,13S)-18-amino-13-({(2S)-2-[(2-carbamoylhydrazino)carbonyl]-1-pyrrolidinyl}carbonyl)-4-(4-hydroxybenzyl)-1-(hydroxymethyl)-18-imino-10-isobutyl-7-{[(2-methyl-2-p
# ropanyl)oxy]methyl}-2,5,8,11-tetraoxo-3,6,9,12,17-pentaazaoctadec-1-yl]-L-tryptophanamide was not found in NPASS DB
# 0 matches were found
# Cobicistat was not found in NPASS DB
# 0 matches were found
# Cometriq was not found in NPASS DB
# 0 matches were found
# Cabozantinib was not found in NPASS DB
# 0 matches were found
# Tafinlar was not found in NPASS DB
# 0 matches were found
# Dabrafenib was not found in NPASS DB
# 0 matches were found
# Cariprazine was not found in NPASS DB
# 0 matches were found
# Ceftolozane was not found in NPASS DB
# 0 matches were found
# Sofosbuvir was not found in NPASS DB
# 0 matches were found
# Alectinib was not found in NPASS DB
# 0 matches were found
# MVI was not found in NPASS DB
# 30926 matches were found
# 0 matches were found
# Firmagon was not found in NPASS DB
# 0 matches were found
# N-Acetyl-3-(2-naphthyl)-D-alanyl-4-chloro-D-phenylalanyl-3-(3-pyridinyl)-D-alanyl-L-seryl-4-({[(4R)-2,6-dioxohexahydro-4-pyrimidinyl]carbonyl}amino)-L-phenylalanyl-4-(carbamoylamino)-D-phenylalanyl-L-
# leucyl-N6-isopropyl-L-lysylprolyl-D-alaninamide was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Clorazepate was not found in NPASS DB
# 0 matches were found
# 7-Chloro-2-oxo-5-phenyl-2,3-dihydro-1H-1,4-benzodiazepine-3-carboxylate was not found in NPASS DB
# 0 matches were found
# Colistimethate was not found in NPASS DB
# 0 matches were found
# 004U31C6CW was not found in NPASS DB
# 0 matches were found
# Canagliflozin was not found in NPASS DB
# 0 matches were found
# Letermovir was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Plazomicin was not found in NPASS DB
# 0 matches were found
# Imbruvica was not found in NPASS DB
# 0 matches were found
# Ibrutinib was not found in NPASS DB
# 0 matches were found
# Telotristat was not found in NPASS DB
# 0 matches were found
# Apalutamide was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Doravirine was not found in NPASS DB
# 15 matches were found
# 0 matches were found
# Florbetapir was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# 6867Q6IKOD was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Romidepsin was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Rolapitant was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Zurampic was not found in NPASS DB
# 0 matches were found
# Lesinurad was not found in NPASS DB
# 0 matches were found
# Lusutrombopag was not found in NPASS DB
# 0 matches were found
# Plecanatide was not found in NPASS DB
# 0 matches were found
# Naldemedine was not found in NPASS DB
# 0 matches were found
# Valbenazine was not found in NPASS DB
# 0 matches were found
# Encorafenib was not found in NPASS DB
# 0 matches were found
# Naloxegol was not found in NPASS DB
# 0 matches were found
# Aristada was not found in NPASS DB
# 0 matches were found
# Aripiprazole lauroxil was not found in NPASS DB
# 0 matches were found
# Ledipasvir was not found in NPASS DB
# 0 matches were found
# Venetoclax was not found in NPASS DB
# 0 matches were found
# Zykadia was not found in NPASS DB
# 0 matches were found
# Ceritinib was not found in NPASS DB
# 0 matches were found
# Abemaciclib was not found in NPASS DB
# 0 matches were found
# Dasabuvir was not found in NPASS DB
# 0 matches were found
# Arranon was not found in NPASS DB
# 30926 matches were found
# 0 matches were found
# 0 matches were found
# Ribociclib was not found in NPASS DB
# 0 matches were found
# Vinorelbine was not found in NPASS DB
# 0 matches were found
# Osimertinib was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Goserelin Acetate was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# (2S)-N-[(2S,5S,8S,11S,14R,17R,20S)-25-Amino-20-({(2S)-2-[(2-carbamoylhydrazino)carbonyl]-1-pyrrolidinyl}carbonyl)-11-(4-hydroxybenzyl)-8-(hydroxymethyl)-1-(1H-imidazol-4-yl)-25-imino-5-(1H-indol-3-ylm
# ethyl)-17-isobutyl-14-{[(2-methyl-2-propanyl)oxy]methyl}-3,6,9,12,15,18-hexaoxo-4,7,10,13,16,19,24-heptaazapentacosan-2-yl]-5-oxo-2-pyrrolidinecarboxamide was not found in NPASS DB
# 0 matches were found
# Ombitasvir was not found in NPASS DB
# 0 matches were found
# Orbactiv was not found in NPASS DB
# 0 matches were found
# oritavancin was not found in NPASS DB
# 0 matches were found
# Sugammadex was not found in NPASS DB
# 0 matches were found
# Paritaprevir was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Prasugrel was not found in NPASS DB
# 0 matches were found
# (R)-Prasugrel was not found in NPASS DB
# 0 matches were found
# Velpatasvir was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Netarsudil was not found in NPASS DB
# 0 matches were found
# Pegaptanib was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# glecaprevir was not found in NPASS DB
# 0 matches were found
# Calquence was not found in NPASS DB
# 0 matches were found
# acalabrutinib was not found in NPASS DB
# 0 matches were found
# Enasidenib was not found in NPASS DB
# 0 matches were found
# Ivosidenib was not found in NPASS DB
# 0 matches were found
# Epoetin Alfa was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# (4R,5S,6S,7R,9R,10R,11Z,13Z,16R)-10-{[(2R,4R,5S,6S)-4,5-Dihydroxy-4,6-dimethyltetrahydro-2H-pyran-2-yl]oxy}-6-{[(2S,3R,4R,5S,6R)-5-{[(2S,4R,5S,6S)-4,5-dihydroxy-4,6-dimethyltetrahydro-2H-pyran-2-yl]ox
# y}-4-(dimethylamino)-3-hydroxy-6-methyltetrahydro-2H-pyran-2-yl]oxy}-4-hydroxy-7-(2-hydroxyethyl)-5-methoxy-9,16-dimethyloxacyclohexadeca-11,13-dien-2-one (non-preferred name) was not found in NPASS DB
# 0 matches were found
# Ibritumomab Tiuxetan was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Ibritumomab was not found in NPASS DB
# 0 matches were found
# Natalizumab was not found in NPASS DB
# 0 matches were found
# (2S,5S,8S,11R,14S,17S,20S,23S,26S,29S,32S)-17-[(2S)-2-Butanyl]-32-formyl-6,13,18,21,24,27,30,34-octahydroxy-26-[(1R)-1-hydroxyethyl]-2-(2-hydroxy-2-iminoethyl)-14-(3-hydroxy-3-iminopropyl)-34-imino-20
# -isobutyl-5,23,29-trimethyl-8-[2-(methylsulfanyl)ethyl]-9,10-dioxo-11-(selanylmethyl)-3,4,7,12,15,16,19,22,25,28,31-undecaazatetratriaconta-6,12,18,21,24,27,30-heptaen-1-oic acid was not found in NPASS DB
# 0 matches were found
# Cholestyramine was not found in NPASS DB
# 0 matches were found
# (Z)-1-(Chol-2-en-3-yl)-2-phenylethenamine was not found in NPASS DB
# 1 matches were found
# 1 matches were found
# 1 matches were found
# 1 matches were found
# 1 matches were found
# 1 matches were found
# 185 matches were found
# 1 matches were found
# 185 matches were found
# 185 matches were found
# 1 matches were found
# 1 matches were found
# 185 matches were found
# 185 matches were found
# 185 matches were found
# 1 matches were found
# 1 matches were found
# 1 matches were found
# 0 matches were found
# 0 matches were found
# Afatinib was not found in NPASS DB
# 0 matches were found
# Acalabrutinib was not found in NPASS DB
# 0 matches were found
# 0 matches were found
# Eribulin was not found in NPASS DB
# 0 matches were found
# Zestril was not found in NPASS DB
# 0 matches were found
# N2-(1-Carboxy-3-phenylpropyl)lysyl-L-proline was not found in NPASS DB

# %%
dff.head()
# Out:
#    ChemSpider_ID                                       InChI_string  \
# 0            103  InChI=1S/C3H5O7P/c4-2(3(5)6)1-10-11(7,8)9/h1H2...
# 1            134  InChI=1S/C5H9NO3/c6-3-4(7)1-2-5(8)9/h1-3,6H2,(...
# 2            140  InChI=1S/C20H23N7O7/c21-20-25-16-15(18(32)26-2...
# 3            185  InChI=1S/C5H5N5/c6-4-3-5(9-1-7-3)10-2-8-4/h1-2...
# 4            235            InChI=1S/C7H6O/c8-6-7-4-2-1-3-5-7/h1-6H
#
#                     Std_InChI Molecular_Formula  Average_Mass  \
# 0  LFLUCDOSQPJJBEUHFFFAOYSA-N           C3H5O7P       184.041
# 1  ZGXJTSGNIOSYLOUHFFFAOYSA-N           C5H9NO3       131.130
# 2  VVIAGPKUTFNRDUUHFFFAOYSA-N        C20H23N7O7       473.439
# 3  GFFGJBXGBJISGVUHFFFAOYSA-N            C5H5N5       135.127
# 4  HUMNYLRZRPPJDNUHFFFAOYSA-N             C7H6O       106.122
#
#                                               SMILES  \
# 0                           C(C(=O)C(=O)O)OP(=O)(O)O
# 1                                  C(CC(=O)O)C(=O)CN
# 2  c1cc(ccc1C(=O)NC(CCC(=O)O)C(=O)O)NCC2CNc3c(c(=...
# 3                               c1[nH]c(c-2ncnc2n1)N
# 4                                      c1ccc(cc1)C=O
#
#                         Common_Name  \
# 0  HPV / 3-Phosphonooxypyruvic acid
# 1               Aminolevulinic Acid
# 2         Leucovorin / folinic acid
# 3                     ADE / Adenine
# 4                      Benzaldehyde
#
#                                      Systematic_Name  logP  H_Bond_Donors  \
# 0               2-Oxo-3-(phosphonooxy)propanoic acid -2.91              3
# 1                        5-Amino-4-oxopentanoic acid -0.93              3
# 2  N-(4-{[(2-Amino-5-formyl-4-oxo-1,4,5,6,7,8-hex... -3.19              8
# 3                                   1H-Purin-6-amine -2.12              3
# 4                                       Benzaldehyde  1.64              0
#
#          ...            Enthalpy_Vap        Density  \
# 0        ...         75.5±6.0 kJ/mol  1.9±0.1 g/cm3
# 1        ...         59.2±6.0 kJ/mol  1.2±0.1 g/cm3
# 2        ...                          1.7±0.1 g/cm3
# 3        ...         48.0±3.0 kJ/mol  1.9±0.1 g/cm3
# 4        ...         41.5±3.0 kJ/mol  1.0±0.1 g/cm3
#
#                Boiling_Point  Arom_rings Num_Nitrogens Num_Oxygens SSSR  \
# 0  432.4±47.0 °C at 760 mmHg           0             0           7    0
# 1  298.4±20.0 °C at 760 mmHg           0             1           3    0
# 2                                      2             7           7    3
# 3  243.2±50.0 °C at 760 mmHg           2             5           0    2
# 4   178.7±0.0 °C at 760 mmHg           1             0           1    1
#
#    Stereocenters   is_NP  Veber_Violations
# 0              0  non-NP                 0
# 1              0      NP                 0
# 2              0      NP                 1
# 3              0      NP                 0
# 4              0      NP                 0
#
# [5 rows x 24 columns]

# %%
#from sqlalchemy import create_engine

disk_engine = create_engine('sqlite:///CSdb_addn.db',echo=False)
connection = disk_engine.raw_connection()
dff.to_sql('CSdb_addn', connection)
#checkDF = pd.read_sql_query('SELECT * FROM CSdb_addn LIMIT 3',disk_engine)
#checkDF.head()

# %%
checkDF = pd.read_sql_query('SELECT * FROM CSdb_addn LIMIT 3',connection)
checkDF.head()
# Out:
#    index  ChemSpider_ID                                       InChI_string  \
# 0      0            103  InChI=1S/C3H5O7P/c4-2(3(5)6)1-10-11(7,8)9/h1H2...
# 1      1            134  InChI=1S/C5H9NO3/c6-3-4(7)1-2-5(8)9/h1-3,6H2,(...
# 2      2            140  InChI=1S/C20H23N7O7/c21-20-25-16-15(18(32)26-2...
#
#                     Std_InChI Molecular_Formula  Average_Mass  \
# 0  LFLUCDOSQPJJBEUHFFFAOYSA-N           C3H5O7P       184.041
# 1  ZGXJTSGNIOSYLOUHFFFAOYSA-N           C5H9NO3       131.130
# 2  VVIAGPKUTFNRDUUHFFFAOYSA-N        C20H23N7O7       473.439
#
#                                               SMILES  \
# 0                           C(C(=O)C(=O)O)OP(=O)(O)O
# 1                                  C(CC(=O)O)C(=O)CN
# 2  c1cc(ccc1C(=O)NC(CCC(=O)O)C(=O)O)NCC2CNc3c(c(=...
#
#                         Common_Name  \
# 0  HPV / 3-Phosphonooxypyruvic acid
# 1               Aminolevulinic Acid
# 2         Leucovorin / folinic acid
#
#                                      Systematic_Name  logP        ...         \
# 0               2-Oxo-3-(phosphonooxy)propanoic acid -2.91        ...
# 1                        5-Amino-4-oxopentanoic acid -0.93        ...
# 2  N-(4-{[(2-Amino-5-formyl-4-oxo-1,4,5,6,7,8-hex... -3.19        ...
#
#       Enthalpy_Vap        Density              Boiling_Point  Arom_rings  \
# 0  75.5±6.0 kJ/mol  1.9±0.1 g/cm3  432.4±47.0 °C at 760 mmHg           0
# 1  59.2±6.0 kJ/mol  1.2±0.1 g/cm3  298.4±20.0 °C at 760 mmHg           0
# 2                   1.7±0.1 g/cm3                                      2
#
#    Num_Nitrogens Num_Oxygens SSSR Stereocenters   is_NP  Veber_Violations
# 0              0           7    0             0  non-NP                 0
# 1              1           3    0             0      NP                 0
# 2              7           7    3             0      NP                 1
#
# [3 rows x 25 columns]

# %%
dff.ix[:,dff.columns[[0,5,6,21]]]
# Out:
# /usr/local/miniconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#       ChemSpider_ID                                             SMILES  \
# 0               103                           C(C(=O)C(=O)O)OP(=O)(O)O
# 1               134                                  C(CC(=O)O)C(=O)CN
# 2               140  c1cc(ccc1C(=O)NC(CCC(=O)O)C(=O)O)NCC2CNc3c(c(=...
# 3               185                               c1[nH]c(c-2ncnc2n1)N
# 4               235                                      c1ccc(cc1)C=O
# 5               292       c1cc(ccc1C(C(CO)NC(=O)C(Cl)Cl)O)[N+](=O)[O-]
# 6               299                                     C[N+](C)(C)CCO
# 7               431                     CC(C(=O)c1cccc(c1)Cl)NC(C)(C)C
# 8               566                                  CN(CC(=O)O)C(=N)N
# 9               659                                            CS(=O)C
# 10              661                                  c1cc(c(cc1CCN)O)O
# 11              733                                         C(C(CO)O)O
# 12              764                                       c1cc(ccc1O)O
# 13              815                              CNCC(c1ccc(c(c1)O)O)O
# 14              911                                   c1cc(cnc1)C(=O)N
# 15              913                                   c1cc(cnc1)C(=O)O
# 16              917                                   CN1CCCC1c2cccnc2
# 17              937                                                  O
# 18              979                                         OP(=O)(O)O
# 19              989                            C[N+](C)(C)CCOP(=O)(O)O
# 20             1017                                   c1cnc(cn1)C(=O)N
# 21             1020                                           c1ccncc1
# 22             1032                                [O-]P(=O)([O-])[O-]
# 23             1042             CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CCO)C)C
# 24             1085                                  [O-]S(=O)(=O)[O-]
# 25             1141                               c1c[nH]c(=O)[nH]c1=O
# 26             1143                                          C(=O)(N)N
# 27             1169                                    CC(Cc1ccccc1)NC
# 28             1262                       CC(c1ccc2cc(ccc2c1)OC)C(=O)O
# 29             1556                             CC(Cc1ccc2c(c1)OCO2)NC
# ...             ...                                                ...
# 1158       35013015  CC1(CC1)S(=O)(=O)NC(=O)[C@]2(C[C@H]2C(F)F)NC(=...
# 1159       36764951  CC#CC(=O)N1CCC[C@H]1c2nc(c3n2ccnc3N)c4ccc(cc4)...
# 1160       38772329  CC(C)(CNc1nc(nc(n1)Nc2ccnc(c2)C(F)(F)F)c3cccc(...
# 1161       38772333  c1ccc(c(c1)[C@@H](C(=O)NC2CC(C2)(F)F)N(c3cc(cn...
# 3                                         ADE / Adenine           2
# 4                                          Benzaldehyde           1
# 5     CAF / 2,2-Dichloro-N-[1,3-dihydroxy-1-(4-nitro...           1
# 6                                               Choline           0
# 7                                Wellbutrin / bupropion           1
# 8                                              Creatine           0
# 9                        Sclerosol / Dimethyl sulfoxide           0
# 10                                             Dopamine           1
# 11                                  Glycerol / glycerin           0
# 12                                         Hydroquinone           1
# 13                              Epinephrin / adrenaline           1
# 14                                         Nicotinamide           1
# 15                                     Niaspan / Niacin           1
# 16                              Nicoderm / (±)-nicotine           1
# 17                                          ICE / Water           0
# 18                     Phosphoricacid / Phosphoric acid           0
# 19                 CHOP / Phosphocholine conjugate acid           0
# 20                                         Pyrazinamide           1
# 21                                             Pyridine           1
# 22                       Phosphate / Phosphate trianion           0
# 23                                              Retinol           0
# 24                           Sulphate / Sulfate dianion           0
# 25                                               Uracil           1
# 26                                                 Urea           0
# 27                  Methamphetamine / (±)-Metamfetamine           1
# 28                                             Naproxen           2
# 29             3,4-Methylenedioxymethamphetamine / MDMA           1
# ...                                                 ...         ...
# 1158                                        glecaprevir           2
# 1159                          Calquence / acalabrutinib           4
# 1160                                         Enasidenib           3
# 1161                                         Ivosidenib           3
# 1162  Epoetin Alfa / (4R,5S,6S,7R,9R,10R,11Z,13Z,16R...           0
# 1163                 Ibritumomab Tiuxetan / Ibritumomab           1
# 1164  Natalizumab / (2S,5S,8S,11R,14S,17S,20S,23S,26...           0
# 1165  Cholestyramine / (Z)-1-(Chol-2-en-3-yl)-2-phen...           1
# 1166  PEB / 3-[2-[(Z)-[3-(2-carboxyethyl)-4-methyl-5...           2
# 1167  PEB / 3-[(2Z)-2-[[3-(2-carboxyethyl)-4-methyl-...           2
# 1168  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(3...           2
# 1169  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[[4...           2
# 1170  PEB / 3-[2-[[3-(2-carboxyethyl)-5-[(Z)-(3-ethy...           2
# 1171  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z...           2
# 1172  TAC / (2S,4aS,5aS,6S,12aS)-4-(Dimethylamino)-3...           1
# 1173  PEB / 3-[2-[[3-(2-carboxyethyl)-5-[(Z)-(3-ethy...           2
# 1174  TAC / (2R,4S,4aS,5aS,6S,12aS)-4-(Dimethylamino...           1
# 1175  TAC / (1S,4S,4aS,5aS,6S,12S,12aS)-4-(Dimethyla...           1
# 1176  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z...           2
# 1177  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z...           2
# 1178  TAC / (4aS,5aS,6S,12S,12aS)-4-(Dimethylamino)-...           1
# 1179  TAC / (2S,4aS,5aS,6S,12aS)-4-(Dimethylamino)-3...           1
# 1180  TAC / (1S,4S,4aS,5aS,6S,12aR)-4-(Dimethylamino...           1
# 1181  PEB / 3-[2-[[3-(2-carboxyethyl)-5-[(4-ethyl-3-...           2
# 1182  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(Z...           2
# 1183  PEB / 3-[2-[[3-(2-carboxyethyl)-4-methyl-5-[(3...           2
# 1184                                           Afatinib           3
# 1185                                      Acalabrutinib           4
# 1186                                           Eribulin           0
# 1187  Zestril / N2-(1-Carboxy-3-phenylpropyl)lysyl-L...           1
#
# [1188 rows x 4 columns]

# %%
def nameSplit(name):
    if '/' in name:
        name = name.split('/')
        name_one = name[0]
        name_two = name[1]
    return [name_one,name_two]

def findSrc(drugName):
    uClient=ureq(searchlink+drugName)
    pagehtml = uClient.read()
    soupPage = soup(pagehtml,'html.parser')
    soupPage.find()
    
import npass_srchDB

# %%
dff.iloc[1185,5]
# Out:
# 'CC#CC(=O)N1CCCC1c2nc(c3n2ccnc3N)c4ccc(cc4)C(=O)Nc5ccccn5'

# %%
for i,j in enumerate(dff.columns):
    print(str(i)+'...'+j)
# Out:
# 0...ChemSpider_ID
# 1...InChI_string
# 2...Std_InChI
# 3...Molecular_Formula
# 4...Average_Mass
# 5...SMILES
# 6...Common_Name
# 7...Systematic_Name
# 8...logP
# 9...H_Bond_Donors
# 10...H_Bond_Acceptors
# 11...Num_Rota_Bonds
# 12...Lipinski_Rule_5
# 13...Polar_Surface_Area
# 14...Enthalpy_Vap
# 15...Density
# 16...Boiling_Point
# 17...Num_Nitrogens
# 18...Num_Oxygens
# 19...Stereocenters
# 20...SSSR
# 21...Arom_rings
# 22...Veber_Violations

# %%
dff_features = dff.iloc[:,[4,8,9,10,11,12,13,17,18,19,20,21,22]]
dff_subset = dff.iloc[:,[4,8,9,10]]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
#from sklearn import preprocessing

# %%
scaled_data = StandardScaler().fit_transform(dff_features.values.astype(float))

# %%
scaled_data = preprocessing.scale(dff_features.values.astype(float))

# %%
scaled_data.shape
# Out:
# (1188, 13)

# %%
mean_vec = np.mean(scaled_data,axis=0)
cov_mat = (scaled_data - mean_vec).T.dot((scaled_data - mean_vec))/(scaled_data.shape[0]-1)

# %%
cov_mat.shape
# Out:
# (13, 13)

# %%
eig_vals, eig_vecs = np.linalg.eig(cov_mat)
print('USING COVARIANCE MATRIX:\n eigen vectors: \n{}\n \t ###################### \n eigen values: \n{}\n'.format(eig_vecs,eig_vals))
# Out:
# USING COVARIANCE MATRIX:
#  eigen vectors:
# [[ 3.41358039e-01 -1.21008637e-01  2.55065796e-02 -1.11823149e-01
#    1.54762354e-01 -4.25507860e-02  4.89588035e-02  2.59828843e-01
#   -1.64222313e-01 -3.30271321e-02 -8.55344930e-01  1.81676552e-02
#    1.37008647e-03]
#  [-9.49670179e-02 -5.21575697e-01  2.33708507e-01 -4.36150127e-02
#    7.10824522e-01  1.41102445e-01 -9.16567384e-02 -1.16484462e-02
#    3.41534928e-01  3.66458306e-02  9.43308095e-02 -5.56059880e-03
#    4.22117416e-02]
#  [ 3.29566591e-01  1.70150872e-01 -1.36616598e-01 -7.99229681e-02
#    3.53173093e-02  1.46524263e-01 -2.78378253e-01 -4.41772310e-01
#    2.52567810e-01 -6.06138086e-01 -6.18826766e-02 -5.54542374e-03
#    3.27039407e-01]
#  [ 3.52088461e-01  6.48868043e-02 -1.04296546e-01 -6.03180599e-02
#    4.01985827e-03 -4.86043188e-03 -2.19439040e-02  2.67200071e-01
#    1.48017047e-01  2.26316420e-01  1.63227904e-01 -7.98363995e-01
#    2.19621492e-01]
#  [ 3.11403554e-01  2.97350878e-02 -1.61651678e-01 -2.88500166e-02
# 0.25999931074011823
# 0.17435569965341294
# 0.1272279223955483
# 0.10260776447167569
# 0.06987701415199463
# 0.04258599244937635
# 0.0166306175475388
# 0.0013875985874448138

# %%
eig_pairs
# Out:
# [(7.746097485155171,
#   array([ 0.34135804, -0.09496702,  0.32956659,  0.35208846,  0.31140355,
#           0.25931728,  0.34752698,  0.28681507,  0.32698052,  0.25977808,
#           0.14599792,  0.09378982,  0.26477762])),
#  (1.9072075488249165,
#   array([-0.12100864, -0.5215757 ,  0.17015087,  0.0648868 ,  0.02973509,
#          -0.15809517,  0.11911745,  0.00373138,  0.09972596,  0.0638423 ,
#          -0.55315463, -0.56345905, -0.05084958])),
#  (1.0767804466395334,
#   array([ 0.02550658,  0.23370851, -0.1366166 , -0.10429655, -0.16165168,
#           0.32929857, -0.084941  , -0.48453009,  0.21275901,  0.45837297,
#           0.12929996, -0.45630914,  0.24150775])),
#  (0.8278844684041702,
#   array([-0.11182315, -0.04361501, -0.07992297, -0.06031806, -0.02885002,
#           0.51514277, -0.04387094,  0.05537037, -0.12998697, -0.47184777,
#          -0.30180708,  0.04312346,  0.6098265 ])),
#  (0.6583101107600668,
#   array([ 0.15476235,  0.71082452,  0.03531731,  0.00401986,  0.46221212,
#          -0.11489067,  0.00885933,  0.07146273, -0.04414671, -0.08396953,
#          -0.41767384, -0.2222717 , -0.06806147])),
#  (0.25999931074011823,
#   array([-0.04255079,  0.14110244,  0.14652426, -0.00486043, -0.31487532,
#           0.32161271,  0.01469309,  0.57391248, -0.46264325,  0.16516783,
#           0.1353492 , -0.35615761, -0.19526159])),
#  (0.17435569965341294,
#   array([ 0.0489588 , -0.09165674, -0.27837825, -0.0219439 ,  0.2161572 ,
#          -0.50123003, -0.11928492,  0.23971129, -0.21335389,  0.0514222 ,
#           0.33206041, -0.29107148,  0.5462869 ])),
#  (0.1272279223955483,
#   array([ 0.25982884, -0.01164845, -0.44177231,  0.26720007, -0.09734227,
#           0.10411654,  0.07039868,  0.09743884,  0.35708103, -0.51034659,
#           0.21918404, -0.35223625, -0.26637575])),
#  (0.10260776447167569,
#   array([-0.16422231,  0.34153493,  0.25256781,  0.14801705, -0.5926395 ,
#          -0.37622274,  0.36604353,  0.02645167,  0.21371964, -0.14289609,
#          -0.03129784, -0.00825388,  0.27584348])),
#  (0.06987701415199463,
#   array([-0.03302713,  0.03664583, -0.60613809,  0.22631642, -0.19810216,
#          -0.01238459, -0.04946244,  0.31076253,  0.13230959,  0.41976372,
#          -0.41287457,  0.27367762,  0.03812889])),
#  (0.04258599244937635,
#   array([-0.85534493,  0.09433081, -0.06188268,  0.1632279 ,  0.32235195,
#           0.1071574 ,  0.07169901,  0.11105723,  0.21537583,  0.00576402,
#           0.20505618, -0.05722219, -0.0663596 ])),
#  (0.0166306175475388,
#   array([ 0.00137009,  0.04221174,  0.32703941,  0.21962149, -0.10870001,
#          -0.04540376, -0.83242758,  0.17383999,  0.3174177 , -0.03986352,
#          -0.01812235, -0.01861353,  0.05455931])),
#  (0.0013875985874448138,
#   array([ 1.81676552e-02, -5.56059880e-03, -5.54542374e-03, -7.98363995e-01,
#          -1.25804600e-03,  1.81659837e-03,  4.36615013e-02,  3.72320458e-01,
#           4.70784826e-01,  4.58757685e-03,  7.40256886e-04,  2.31311320e-03,
#          -4.91597151e-03]))]

# %%
#explained variance can be calculated from the eigenvalues; which can be attributed to each of the principal components
tot = sum(eig_vals) # 3.9999
var_exp = [(i/tot)*100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)

# %%
plt.figure(figsize=(6, 4))
plt.bar(range(13), var_exp, alpha=0.5, align='center',
        label='individual explained variance')
plt.step(range(13), cum_var_exp, where='mid',
         label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.legend(loc='best')
#Together, the first two principal components contain 95.8% of the information.

# %%
matrix_w = np.hstack((eig_pairs[0][1].reshape(13,1),
                      eig_pairs[1][1].reshape(13,1),
                      eig_pairs[2][1].reshape(13,1),
                      eig_pairs[3][1].reshape(13,1)))
matrix_w #a 13x4 projection matrix with the concatenated top k eigenvectors
# Out:
# array([[ 0.34135804, -0.12100864,  0.02550658, -0.11182315],
#        [-0.09496702, -0.5215757 ,  0.23370851, -0.04361501],
#        [ 0.32956659,  0.17015087, -0.1366166 , -0.07992297],
#        [ 0.35208846,  0.0648868 , -0.10429655, -0.06031806],
#        [ 0.31140355,  0.02973509, -0.16165168, -0.02885002],
#        [ 0.25931728, -0.15809517,  0.32929857,  0.51514277],
#        [ 0.34752698,  0.11911745, -0.084941  , -0.04387094],
#        [ 0.28681507,  0.00373138, -0.48453009,  0.05537037],
#        [ 0.32698052,  0.09972596,  0.21275901, -0.12998697],
#        [ 0.25977808,  0.0638423 ,  0.45837297, -0.47184777],
#        [ 0.14599792, -0.55315463,  0.12929996, -0.30180708],
#        [ 0.09378982, -0.56345905, -0.45630914,  0.04312346],
#        [ 0.26477762, -0.05084958,  0.24150775,  0.6098265 ]])

# %%
datamat = scaled_data.dot(matrix_w)

# %%
datamat.shape
# Out:
# (1188, 4)

# %%
plt.figure(figsize=(6, 4))
plt.scatter(datamat[:,0],datamat[:,1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
# Out:
# Text(0, 0.5, 'Principal Component 2')

# %%
pca = PCA().fit(scaled_data)
pca_data = pca.transform(scaled_data)
per_var = np.round(pca.explained_variance_ratio_* 100, decimals=1) #percent variation
labels = ['PC' + str(x) for x in range(1, len(per_var)+1)]
 
plt.bar(range(1,len(per_var)+1), per_var, tick_label=labels)
plt.ylabel('Percentage of Explained Variance')
plt.xlabel('Principal Component')
plt.title('Scree Plot')
# Out:
# Text(0.5, 1.0, 'Scree Plot')

# %%
pca = PCA().fit(scaled_data)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
pca_df = pd.DataFrame(pca_data,index =dff.ChemSpider_ID ,columns=labels)
pca_df
# Out:
#                     PC1       PC2       PC3       PC4       PC5       PC6  \
# ChemSpider_ID
# 103           -0.831432 -2.527687 -0.239245  0.531224 -0.166161  0.954741
# 134           -1.447839 -2.043635 -0.350731  0.007215 -0.128409  0.256065
# 140            2.012267 -0.885011 -1.235064  0.999596 -1.386967 -0.042097
    pcadf_dict[pca_df.columns[i]] = pca_df[pca_df.columns[i]]
pcadf_dict
# Out:
# {'PC1': ChemSpider_ID
#  103        -0.831432
#  134        -1.447839
#  140         2.012267
#  185        -1.119724
#  235        -2.274355
#  292        -0.622193
#  299        -1.988538
#  431        -1.848906
#  566        -1.216239
#  659        -2.322355
#  661        -1.482843
#  733        -1.697026
#  764        -1.955560
#  815        -1.248733
#  911        -1.695603
#  913        -1.797286
#  917        -1.965299
#  937        -2.359183
#  979        -1.573630
#  989        -1.200405
#  1017       -1.520229
#  1020       -2.309537
#  1032       -1.554806
#  1042       -1.844481
#  1085       -1.678527
#  1141       -1.598015
#  1143       -1.702306
#  1169       -2.101045
#  1262       -1.583315
#  1556       -1.684308
#                ...
#  35013015    2.651224
#  36764951    0.365918
#  38772329   -0.058687
#  38772333    0.725360
#  52563936    3.949393
#  57269045    2.654395
#  57269055    8.191764
#  57620495   -0.956620
#  61709079    1.864700
#  61709081    1.839646
#  61709082    1.710536
#  61709083    1.802797
#  61709084    1.616278
#  61711402    1.765812
#  61712312    0.834841
#  61713038    1.603527
#  61713125    0.848762
#  61713877    1.084354
#  61715280    1.753061
#  61715281    1.723600
#  61715536    0.971483
#  61715772    0.834841
#  61715978    1.031707
#  61716067    1.850477
#  61716085    1.753061
#  61716287    1.863229
#  64870107   -0.030646
#  64870108    0.306551
#  65323053    2.448919
#  67026656    0.375719
#  Name: PC1, Length: 1188, dtype: float64, 'PC2': ChemSpider_ID
#  103        -2.527687
#  134        -2.043635
#  140        -0.885011
#  185        -0.897781
#  235        -0.727454
#  292        -1.061864
#  299        -2.382921
#  431        -0.395185
#  566        -2.238303
#  659        -1.939373
#  661        -1.186554
#  733        -2.284179
#  764        -1.014156
#  815        -1.345822
#  911        -1.146613
#  913        -1.083775
#  917        -0.578995
#  937        -2.000988
#  979        -2.296643
#  989        -2.750894
#  1017       -1.210833
#  1020       -0.876635
#  1032       -2.304862
#  1042        0.025305
#  1085       -2.064140
#  1141       -1.286086
#  1143       -2.250453
#  1169       -0.665795
#  1262        0.098372
#  1556       -0.465173
#                ...
#  35013015    1.294869
#  36764951    1.198354
#  38772329    0.951431
#  38772333    0.976515
#  52563936   -0.470156
#  57269045   -0.848453
#  57269055   -1.373010
#  57620495    2.332669
#  61709079    0.503152
#  61709081    0.749068
#  61709082    0.556954
#  61709083    0.504281
#  61709084    0.850449
#  61711402    0.811826
#  61712312    0.230958
#  61713038    0.929235
#  61713125   -0.205679
#  61713877   -0.329750
#  61715280    0.890612
#  61715281    0.862304
#  61715536    0.240382
#  61715772    0.230958
#  61715978   -0.421889
#  61716067    0.580803
#  61716085    0.890612
#  61716287    0.502017
#  64870107    1.108674
#  64870108    1.210933
#  65323053    1.354202
#  67026656   -0.685600
#  Name: PC2, Length: 1188, dtype: float64, 'PC3': ChemSpider_ID
#  103        -0.239245
#  134        -0.350731
#  140        -1.235064
#  185        -1.447072
#  235        -0.129604
#  292        -0.438405
#  299        -0.578005
#  431        -0.151626
#  566        -0.758899
#  659        -0.197470
#  661        -0.470447
#  64870108    0.144303
#  65323053    0.145942
#  67026656   -0.314118
#  Name: PC9, Length: 1188, dtype: float64, 'PC10': ChemSpider_ID
#  103        -0.109421
#  134        -0.097151
#  140        -0.147967
#  185        -0.059478
#  235        -0.044733
#  292         0.040308
#  299         0.142744
#  431         0.119993
#  566        -0.064882
#  659         0.072436
#  661         0.011125
#  733        -0.023452
#  764        -0.017930
#  815         0.024222
#  911        -0.042568
#  913        -0.067781
#  917         0.010399
#  937        -0.043369
#  979        -0.030566
#  989         0.133948
#  1017       -0.091950
#  1020       -0.040941
#  1032       -0.045644
#  1042        0.065771
#  1085       -0.091518
#  1141       -0.079138
#  1143       -0.029426
#  1169        0.027968
#  1262       -0.010468
#  1556       -0.079102
#                ...
#  35013015    0.216053
#  36764951    0.107621
#  38772329    0.142574
#  38772333    0.229876
#  52563936    0.072951
#  57269045   -0.494567
#  57269055   -0.472597
#  57620495   -0.044471
#  61709079    0.114795
#  61709081    0.104783
#  61709082   -0.065612
#  61709083   -0.012213
#  61709084   -0.098610
#  61711402   -0.034963
#  61712312   -0.155349
#  61713038   -0.108971
#  61713125   -0.067403
#  61713877   -0.021069
#  61715280   -0.045324
#  61715281   -0.005894
#  61715536   -0.144818
#  61715772   -0.155349
#  61715978   -0.011228
#  61716067   -0.008955
#  61716085   -0.045324
#  61716287    0.001406
#  64870107    0.080823
#  64870108    0.113025
#  65323053   -0.217783
#  67026656   -0.129684
#  Name: PC10, Length: 1188, dtype: float64, 'PC11': ChemSpider_ID
#  103         0.047100
#  134         0.005671
#  140        -0.125868
#  185        -0.017866
#  235         0.014401
#  292        -0.016815
#  299        -0.047132
#  431        -0.034952
#  566        -0.042978
#  659         0.143532
#  661        -0.058809
#  733        -0.043651
#  764        -0.054703
#  815        -0.091081
#  911         0.013746
#  913         0.011609
#  917        -0.026570
#  937        -0.213997
#  979         0.011880
#  989         0.004407
#  1017        0.024916
#  1020        0.011359
#  1032        0.063319
#  1042       -0.059920
#  1085        0.065499
#  1141       -0.073329
#  1143       -0.033125
#  1169       -0.040703
#  1262       -0.021374
#  1556       -0.111083
#                ...
#  35013015    0.019282
#  36764951    0.001546
#  38772329   -0.018298
#  38772333    0.141138
#  52563936   -0.204958
#  57269045   -0.108630
#  57269055    0.216140
#  57620495   -0.000666
#  61709079    0.523959
#  61709081    0.427205
#  61709082   -0.008607
#  61709083    0.316524
#  61709084   -0.038708
#  61711402    0.215424
#  61712312   -0.158762
#  61713038   -0.044114
#  61713125   -0.089741
#  61713877   -0.208155
#  61715280    0.210018
#  61715281    0.202758
#  61715536   -0.248508
#  61715772   -0.158762
#  61715978   -0.157192
#  61716067    0.241269
#  61716085    0.210018
#  61716287    0.246676
#  64870107   -0.103759
#  64870108   -0.009522
#  65323053   -0.129179
#  67026656   -0.021265
#  Name: PC11, Length: 1188, dtype: float64, 'PC12': ChemSpider_ID
#  103        -0.010875
#  134        -0.004134
#  140        -0.012344
#  185         0.004461
#  235        -0.001212
#  292        -0.007126
#  299        -0.000035
#  431        -0.000060
#  566        -0.002739
#  659         0.006646
#  661         0.001655
#  733        -0.003485
#  764        -0.001961
#  815        -0.002180
#  911         0.001716
#  913        -0.002727
#  917         0.000661
#  937        -0.009661
#  979        -0.003083
#  989        -0.002940
#  1017        0.000387
#  1020        0.000695
#  1032       -0.000773
#  1042       -0.003624
#  1085       -0.004089
#  1141       -0.005692
#  1143        0.002478
#  1169        0.000845
#  1262       -0.003750
#  1556       -0.008054
#                ...
#  35013015   -0.000763
#  36764951    0.007344
#  38772329    0.003383
#  38772333    0.010461
#  52563936   -0.018017
#  57269045   -0.036202
#  57269055   -0.013209
#  57620495    0.012330
#  61709079    0.024615
#  61709081    0.021351
#  61709082   -0.004495
#  61709083    0.011128
#  61709084   -0.007023
#  61711402    0.007282
#  61712312   -0.013170
#  61713038   -0.007635
#  61713125   -0.009248
#  61713877   -0.007815
#  61715280    0.006670
#  61715281    0.007313
#  61715536   -0.013330
#  61715772   -0.013170
#  61715978   -0.006975
#  61716067    0.009352
#  61716085    0.006670
#  61716287    0.009965
#  64870107   -0.004759
#  64870108    0.006189
#  65323053   -0.006691
#  67026656   -0.006600
#  Name: PC12, Length: 1188, dtype: float64}

# %%
for i in pca_df.columns:
    print(sum(pca_df[i]))
# Out:
# -2.56905607898e-13
# 2.38697950294e-14
# 1.11022302463e-14
# 1.54876111935e-14
# -1.82631687551e-14
# 6.55031584529e-15
# 5.23470156111e-14
# -2.86437540353e-14
# -1.47659662275e-14
# 7.66470220626e-14
# -4.93494134446e-14
# 9.19056497573e-15

# %%
pca_df.mean() #mean of each column
# Out:
# PC1    -5.326828e-16
# PC2     4.784800e-17
# PC3     1.356238e-16
# PC4    -3.219460e-17
# PC5     3.317586e-17
# PC6    -4.896943e-17
# PC7    -3.085121e-17
# PC8    -3.600281e-17
# PC9     2.696122e-17
# PC10    4.763773e-17
# PC11   -4.435519e-17
# PC12    4.611327e-18
# dtype: float64

# %%
pcadf_dict['PC12']

# %%
fig, ax = plt.subplots(12,12, sharex='col', sharey='row',figsize=(22,22))
fig.subplots_adjust(wspace=1,hspace=1)
for i in range(12):
    for j in range(12):
        if i == j:
            pass
        else:
            ax[i,j].scatter(pcadf_dict['PC{}'.format(i+1)], pcadf_dict['PC{}'.format(j+1)])#,edgecolors='black')
            ax[i,j].set_title('PC{} vs. PC{}'.format(i+1,j+1))
#        plt.xlabel('PC1 - {0}%'.format(per_var[0]))
#        plt.ylabel('PC2 - {0}%'.format(per_var[1]))

# %%
fig, ax = plt.subplots(4,4, sharex='col', sharey='row',figsize=(20,20))
fig.subplots_adjust(wspace=1,hspace=1)
for i in range(4):
    for j in range(4):
        if i == j:
            pass
        else:
            ax[i,j].scatter(pcadf_dict['PC{}'.format(i+1)], pcadf_dict['PC{}'.format(j+1)])#,edgecolors='black')
            ax[i,j].set_title('PC{} vs. PC{}'.format(i+1,j+1))

# %%
'''remove water from dictionary'''
for s in outerDict.keys():
    q = outerDict[s]['Common Name']
    m = re.search('water',q,re.IGNORECASE)
    if m:
        print(s)
        outerDict.pop(s) #or del outerDict['937]
